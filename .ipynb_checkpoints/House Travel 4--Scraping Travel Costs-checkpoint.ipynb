# %% [markdown]
# # Scraping Travel Costs

# %%
The last notebook scraped

# %%
import wget
import requests
import pandas as pd
import pytesseract
from pdf2image import convert_from_path
from Andrew import sandwich
import numpy as np
import os
import time
import fitz
import re
import glob
from pathlib import Path
import re

# %%
df=pd.read_csv("International Travel Jan 10.csv")
df
# Out:
#       Unnamed: 0.1  Unnamed: 0                         Dates         Traveler  \
# 0                0           0  Dec. 6, 2023 - Dec. 12, 2023  Vivian Moeglein
# 1                1           1  Dec. 6, 2023 - Dec. 12, 2023    Aniela Butler
# 2                2           2  Dec. 6, 2023 - Dec. 11, 2023   Brandon Mooney
# 3                3           3  Dec. 6, 2023 - Dec. 11, 2023    Craig Wheeler
# 4                4           4  Dec. 7, 2023 - Dec. 11, 2023     Julia Letlow
# ...            ...         ...                           ...              ...
# 1628          6195           4  Nov. 8, 2018 - Nov. 13, 2018   Carlos Curbelo
# 1629          6196           5  Nov. 8, 2018 - Nov. 13, 2018      Peter Welch
# 1630          6197           6  Nov. 7, 2018 - Nov. 12, 2018       Mike Doyle
# 1631          6198           7  Nov. 7, 2018 - Nov. 12, 2018  Josh Gottheimer
# 1632          6199           8  Nov. 7, 2018 - Nov. 12, 2018      John Larson
#
#                       Member Party State / District           Destination  \
# 0            Bruce Westerman     R             AR-4  United Arab Emirates
# 1            Bruce Westerman     R             AR-4  United Arab Emirates
# 2     Cathy McMorris Rodgers     R             WA-5  United Arab Emirates
# 3            Robert E. Latta     R             OH-5  United Arab Emirates
# 4               Julia Letlow     R             LA-5  United Arab Emirates
# ...                      ...   ...              ...                   ...
# 1628          Carlos Curbelo     R            FL-26         Paris, France
# 1629             Peter Welch     D             VT-1         Paris, France
# 1630              Mike Doyle     D             PA-0         Paris, France
# 1631         Josh Gottheimer     D             NJ-5         Paris, France
# 1632          John B. Larson     D             CT-1         Paris, France
#
#                                                 Sponsor Filing Type  \
# 0                       Conservative Climate Foundation    Original
# 1                       Conservative Climate Foundation    Original
# 2                       Conservative Climate Foundation    Original
# 3                       Conservative Climate Foundation    Original
# 4                          Climate Solutions Foundation    Original
# ...                                                 ...         ...
# 1628  Ripon Society and the Franklin Center for Glob...    Original
# 1629  Ripon Society and the Franklin Center for Glob...    Original
# 1630  Ripon Society and the Franklin Center for Glob...    Original
# 1631  Ripon Society and the Franklin Center for Glob...    Original
# 1632  Ripon Society and the Franklin Center for Glob...    Original
#
#                                                   hrefs  Page #  \
# 0     https://disclosures-clerk.house.gov/gtimages/S...       1
# 1     https://disclosures-clerk.house.gov/gtimages/S...       1
# 2     https://disclosures-clerk.house.gov/gtimages/S...       1
# 3     https://disclosures-clerk.house.gov/gtimages/S...       1
# 4     https://disclosures-clerk.house.gov/gtimages/M...       1
# ...                                                 ...     ...
# 1628  https://disclosures-clerk.house.gov/gtimages/M...     152
# 1629  https://disclosures-clerk.house.gov/gtimages/M...     152
# 1630  https://disclosures-clerk.house.gov/gtimages/M...     152
# 1631  https://disclosures-clerk.house.gov/gtimages/M...     152
# 1632  https://disclosures-clerk.house.gov/gtimages/M...     152
#
#           Departure          Return  Year Country
# 0     Dec. 6, 2023    Dec. 12, 2023  2023     UAE
# 1     Dec. 6, 2023    Dec. 12, 2023  2023     UAE
# 2     Dec. 6, 2023    Dec. 11, 2023  2023     UAE
# 3     Dec. 6, 2023    Dec. 11, 2023  2023     UAE
# 4     Dec. 7, 2023    Dec. 11, 2023  2023     UAE
# ...             ...             ...   ...     ...
# 1628  Nov. 8, 2018    Nov. 13, 2018  2018  France
# 1629  Nov. 8, 2018    Nov. 13, 2018  2018  France
# 1630  Nov. 7, 2018    Nov. 12, 2018  2018  France
# 1631  Nov. 7, 2018    Nov. 12, 2018  2018  France
# 1632  Nov. 7, 2018    Nov. 12, 2018  2018  France
#
# [1633 rows x 16 columns]

# %%
df["Raw Costs"]=""
df=df.drop(columns=["Unnamed: 0.1", "Unnamed: 0"])
df
# Out:
#                              Dates         Traveler                  Member  \
# 0     Dec. 6, 2023 - Dec. 12, 2023  Vivian Moeglein         Bruce Westerman
# 1     Dec. 6, 2023 - Dec. 12, 2023    Aniela Butler         Bruce Westerman
# 2     Dec. 6, 2023 - Dec. 11, 2023   Brandon Mooney  Cathy McMorris Rodgers
# 3     Dec. 6, 2023 - Dec. 11, 2023    Craig Wheeler         Robert E. Latta
# 4     Dec. 7, 2023 - Dec. 11, 2023     Julia Letlow            Julia Letlow
# ...                            ...              ...                     ...
# 1628  Nov. 8, 2018 - Nov. 13, 2018   Carlos Curbelo          Carlos Curbelo
# 1629  Nov. 8, 2018 - Nov. 13, 2018      Peter Welch             Peter Welch
# 1630  Nov. 7, 2018 - Nov. 12, 2018       Mike Doyle              Mike Doyle
# 1631  Nov. 7, 2018 - Nov. 12, 2018  Josh Gottheimer         Josh Gottheimer
# 1632  Nov. 7, 2018 - Nov. 12, 2018      John Larson          John B. Larson
#
#      Party State / District           Destination  \
# 0        R             AR-4  United Arab Emirates
# 1        R             AR-4  United Arab Emirates
# 2        R             WA-5  United Arab Emirates
# 3        R             OH-5  United Arab Emirates
# 4        R             LA-5  United Arab Emirates
# ...    ...              ...                   ...
# 1628     R            FL-26         Paris, France
# 1629     D             VT-1         Paris, France
# 1630     D             PA-0         Paris, France
# 1631     D             NJ-5         Paris, France
# 1632     D             CT-1         Paris, France
#
#                                                 Sponsor Filing Type  \
# 0                       Conservative Climate Foundation    Original
# 1                       Conservative Climate Foundation    Original
# 2                       Conservative Climate Foundation    Original
# 3                       Conservative Climate Foundation    Original
# 4                          Climate Solutions Foundation    Original
# ...                                                 ...         ...
# 1628  Ripon Society and the Franklin Center for Glob...    Original
# 1629  Ripon Society and the Franklin Center for Glob...    Original
# 1630  Ripon Society and the Franklin Center for Glob...    Original
# 1631  Ripon Society and the Franklin Center for Glob...    Original
# 1632  Ripon Society and the Franklin Center for Glob...    Original
#
#                                                   hrefs  Page #  \
# 0     https://disclosures-clerk.house.gov/gtimages/S...       1
# 1     https://disclosures-clerk.house.gov/gtimages/S...       1
# 2     https://disclosures-clerk.house.gov/gtimages/S...       1
# 3     https://disclosures-clerk.house.gov/gtimages/S...       1
# 4     https://disclosures-clerk.house.gov/gtimages/M...       1
# ...                                                 ...     ...
# 1628  https://disclosures-clerk.house.gov/gtimages/M...     152
# 1629  https://disclosures-clerk.house.gov/gtimages/M...     152
# 1630  https://disclosures-clerk.house.gov/gtimages/M...     152
# 1631  https://disclosures-clerk.house.gov/gtimages/M...     152
# 1632  https://disclosures-clerk.house.gov/gtimages/M...     152
#
#           Departure          Return  Year Country Raw Costs
# 0     Dec. 6, 2023    Dec. 12, 2023  2023     UAE
# 1     Dec. 6, 2023    Dec. 12, 2023  2023     UAE
# 2     Dec. 6, 2023    Dec. 11, 2023  2023     UAE
# 3     Dec. 6, 2023    Dec. 11, 2023  2023     UAE
# 4     Dec. 7, 2023    Dec. 11, 2023  2023     UAE
# ...             ...             ...   ...     ...       ...
# 1628  Nov. 8, 2018    Nov. 13, 2018  2018  France
# 1629  Nov. 8, 2018    Nov. 13, 2018  2018  France
# 1630  Nov. 7, 2018    Nov. 12, 2018  2018  France
# 1631  Nov. 7, 2018    Nov. 12, 2018  2018  France
# 1632  Nov. 7, 2018    Nov. 12, 2018  2018  France
#
# [1633 rows x 15 columns]

# %%
len(df)
# Out:
# 1633

# %%
#Download and scrape the pdf of a privately-sponsored congressional trip
def read_housefiles(file):
    '''
    Takes a house file(pdf) and reads the entries for traveler cost and accompanying 
    family member cost. Returns "error" if the file cannot be read.
    '''
    print(f"Reading{file}\n")
    doc=convert_from_path(file)
    costs=[]
    print(f"now scraping {file}")
    for page in doc: 
        text=pytesseract.image_to_string(page)
        lower=text.lower()
        if (seektext1 in lower) and (seektext2 in lower):
            costs=sandwich(text, start_text, end_text)
            if costs!="Error making sandwich":
                print(f"trip cost {costs}")
                return costs
                break
            else:
                print(f"unable to scrape costs in {file}")
                return costs
        else:
            pass
    if costs==[]:
        return "error"

# %%
seektext1="actual amount of expenses paid on behalf of"
seektext2="sponsor post-travel disclosure form"
start_text="and description"
end_text="Family Member"

# %%
def fitz_read(file):
    doc=fitz.open(file)
    costs=[]
    for page in doc:
        text=page.get_text()
        lower=text.lower()
        if(seektext1 in lower) and (seektext2 in lower):
            costs=sandwich(text, start_text,end_text)
            if costs!="Error making sandwich":
                print(f"trip cost {costs}")
                return costs
                break
            else:
                print(f"unable to scrape costs in {file}")
                return costs
        else:
            pass
    if costs==[]:
        return "error"

# %%
def cleancosts(string):
    '''
    Takes the string returned by the previous function. Attempts to strip out dollar signs
    and other mischellanea to add up the total cost of a trip. 
    If there's still leftover text, it returns the original string
    '''
    string=str(string)
    newstring=string.strip().replace("Traveler ","").replace("|","").replace("/","").replace("\\","")
    newstring=newstring.replace(" Accompanying ","").replace("1$","")
    newstring=newstring.replace("Accompanying ","")
    newstring=newstring.replace("$","").replace(",","").replace("\n","")
    numblist=newstring.split(" ")
    try:
        numbers=[float(x) for x in numblist]
        return sum(numbers)
    except: 
        string=string

# %%
broken_links=[]
costs_dict=[]
no_forms=[]
for i in range(55, 1634):
    row=df.loc[i]
    raw_costs=[]
    fitz_costs=[]
    destination=row['Country']
        #docfile=row["hrefs"]
    url=row["hrefs"]
    if destination!="USA":
        filename=f"Downloads/{i}{destination}{row['Dates']}.pdf"
        response=requests.get(url)
        if response.status_code<400:
            print(f"now downloading information on {row['Traveler']}'s trip to {destination}' on {row['Dates']}")
            wget.download(url, out=filename)
            raw_costs=read_housefiles(filename)
            if raw_costs=="error":
                no_forms.append([i, row['Traveler'], row['Dates'],destination])
                print(f"No disclosure found in row {i}")
            else:
                print(f"{row['Traveler']}'s trip cost:\n {raw_costs}\n")
            df.loc[i,"Raw Costs"]=raw_costs
            os.remove(filename)
        else:
            print(f"failed to read {row['Traveler']} on {row['Dates']}")
            broken_links.append({"row":i, "traveler":row['Traveler'],"Date":row["Dates"],"url":url})
    else:
        pass
    time.sleep(1)
print("Scraping complete")
# Out:
# now downloading information on William M. "Bill" Christian's trip to France' on Sept. 5, 2023 - Sept. 8, 2023
# ReadingDownloads/55FranceSept. 5, 2023 - Sept. 8, 2023.pdf
#
# now scraping Downloads/55FranceSept. 5, 2023 - Sept. 8, 2023.pdf
# unable to scrape costs in Downloads/55FranceSept. 5, 2023 - Sept. 8, 2023.pdf
# William M. "Bill" Christian's trip cost:
#  Error making sandwich
#
# now downloading information on Randy Weber, Sr.'s trip to France' on Sept. 5, 2023 - Sept. 8, 2023
# ReadingDownloads/56FranceSept. 5, 2023 - Sept. 8, 2023.pdf
#
# now scraping Downloads/56FranceSept. 5, 2023 - Sept. 8, 2023.pdf
# trip cost )
#
# oe . mn PE
#
# Accompanying |N/A
#
# Randy Weber, Sr.'s trip cost:
#  )
#
# oe . mn PE
#
# Accompanying |N/A
#
#
# now downloading information on Chellie Pingree's trip to Norway' on Aug. 26, 2023 - Sept. 5, 2023
# ReadingDownloads/57NorwayAug. 26, 2023 - Sept. 5, 2023.pdf
#
# now scraping Downloads/57NorwayAug. 26, 2023 - Sept. 5, 2023.pdf
# trip cost )
# Traveler $1,075 $280 $692: AV, meeting
# $4,411 (See Appendix) | (See Appendix) | rooms, conference
# services
# Accompanying
#
# Chellie Pingree's trip cost:
#  )
# Traveler $1,075 $280 $692: AV, meeting
# $4,411 (See Appendix) | (See Appendix) | rooms, conference
# services
# Accompanying
#
#
# now downloading information on Mark Pocan's trip to Nepal' on Aug. 25, 2023 - Sept. 4, 2023
# ReadingDownloads/58NepalAug. 25, 2023 - Sept. 4, 2023.pdf
#
# now scraping Downloads/58NepalAug. 25, 2023 - Sept. 4, 2023.pdf
# unable to scrape costs in Downloads/58NepalAug. 25, 2023 - Sept. 4, 2023.pdf
# Mark Pocan's trip cost:
#  Error making sandwich
#
# now downloading information on Earl Blumenauer's trip to Norway' on Aug. 26, 2023 - Sept. 4, 2023
# ReadingDownloads/59NorwayAug. 26, 2023 - Sept. 4, 2023.pdf
#
# now scraping Downloads/59NorwayAug. 26, 2023 - Sept. 4, 2023.pdf
# unable to scrape costs in Downloads/59NorwayAug. 26, 2023 - Sept. 4, 2023.pdf
# Earl Blumenauer's trip cost:
#  Error making sandwich
#
# now downloading information on Susan Wild's trip to Nepal' on Aug. 25, 2023 - Sept. 3, 2023
# ReadingDownloads/60NepalAug. 25, 2023 - Sept. 3, 2023.pdf
#
# now scraping Downloads/60NepalAug. 25, 2023 - Sept. 3, 2023.pdf
# unable to scrape costs in Downloads/60NepalAug. 25, 2023 - Sept. 3, 2023.pdf
# Susan Wild's trip cost:
#  Error making sandwich
#
# now downloading information on John Sarbanes's trip to Norway' on Aug. 24, 2023 - Sept. 3, 2023
# ReadingDownloads/61NorwayAug. 24, 2023 - Sept. 3, 2023.pdf
#
# now scraping Downloads/61NorwayAug. 24, 2023 - Sept. 3, 2023.pdf
# unable to scrape costs in Downloads/61NorwayAug. 24, 2023 - Sept. 3, 2023.pdf
# John Sarbanes's trip cost:
#  Error making sandwich
#
# now downloading information on Alec Daman's trip to Lithuania' on Aug. 27, 2023 - Sept. 2, 2023
# ReadingDownloads/62LithuaniaAug. 27, 2023 - Sept. 2, 2023.pdf
#
# now scraping Downloads/62LithuaniaAug. 27, 2023 - Sept. 2, 2023.pdf
# trip cost )
#
# Traveler $2387.05 $573.48 $570.68 $8.19 Warsaw Uprising
# Museum tour
#
# Private transportation
# $8.26 Museum of
# Accompanying NA N/A N/A Qexeupation and Freedom
#
# Alec Daman's trip cost:
#  )
#
# Traveler $2387.05 $573.48 $570.68 $8.19 Warsaw Uprising
# Museum tour
#
# Private transportation
# $8.26 Museum of
# Accompanying NA N/A N/A Qexeupation and Freedom
#
#
# now downloading information on Monique Bolsajian's trip to Lithuania' on Aug. 27, 2023 - Sept. 2, 2023
# ReadingDownloads/63LithuaniaAug. 27, 2023 - Sept. 2, 2023.pdf
#
# now scraping Downloads/63LithuaniaAug. 27, 2023 - Sept. 2, 2023.pdf
# trip cost )
#
# Traveler $2387.05 $573.48 $570.68 $8.19 Warsaw Uprising
# Museum tour
#
# Private transportation
# $8.26 Museum of
# Accompanying NA N/A N/A Qexeupation and Freedom
#
# Monique Bolsajian's trip cost:
#  )
#
# Traveler $2387.05 $573.48 $570.68 $8.19 Warsaw Uprising
# Museum tour
#
# Private transportation
# $8.26 Museum of
# Accompanying NA N/A N/A Qexeupation and Freedom
#
#
# now downloading information on Sebastian Wigley's trip to Armenia' on Aug. 26, 2023 - Sept. 2, 2023
# ReadingDownloads/64ArmeniaAug. 26, 2023 - Sept. 2, 2023.pdf
#
# now scraping Downloads/64ArmeniaAug. 26, 2023 - Sept. 2, 2023.pdf
# trip cost )
# Traveler
# See attachment
# (Expenses)
# Accompanying
#
# Sebastian Wigley's trip cost:
#  )
# Traveler
# See attachment
# (Expenses)
# Accompanying
#
#
# now downloading information on Victoria Rivas's trip to Lithuania' on Aug. 27, 2023 - Sept. 2, 2023
# ReadingDownloads/65LithuaniaAug. 27, 2023 - Sept. 2, 2023.pdf
#
# now scraping Downloads/65LithuaniaAug. 27, 2023 - Sept. 2, 2023.pdf
# trip cost )
#
# Traveler $2387.05 $573.48 $570.68 $8.19 Warsaw Uprising
# Museum tour
#
# Private transportation
# $8.26 Museum of
# Accompanying NA N/A N/A Qexeupation and Freedom
#
# Victoria Rivas's trip cost:
#  )
#
# Traveler $2387.05 $573.48 $570.68 $8.19 Warsaw Uprising
# Museum tour
#
# Private transportation
# $8.26 Museum of
# Accompanying NA N/A N/A Qexeupation and Freedom
#
#
# now downloading information on Daniel T. Kildee's trip to Nepal' on Aug. 25, 2023 - Sept. 2, 2023
# ReadingDownloads/66NepalAug. 25, 2023 - Sept. 2, 2023.pdf
#
# now scraping Downloads/66NepalAug. 25, 2023 - Sept. 2, 2023.pdf
# unable to scrape costs in Downloads/66NepalAug. 25, 2023 - Sept. 2, 2023.pdf
# Daniel T. Kildee's trip cost:
#  Error making sandwich
#
# now downloading information on Deborah Ross's trip to Norway' on Aug. 26, 2023 - Sept. 2, 2023
# ReadingDownloads/67NorwayAug. 26, 2023 - Sept. 2, 2023.pdf
#
# now scraping Downloads/67NorwayAug. 26, 2023 - Sept. 2, 2023.pdf
# unable to scrape costs in Downloads/67NorwayAug. 26, 2023 - Sept. 2, 2023.pdf
# Deborah Ross's trip cost:
#  Error making sandwich
#
# now downloading information on Jordan Dickinson's trip to Lithuania' on Aug. 27, 2023 - Sept. 2, 2023
# ReadingDownloads/68LithuaniaAug. 27, 2023 - Sept. 2, 2023.pdf
#
# now scraping Downloads/68LithuaniaAug. 27, 2023 - Sept. 2, 2023.pdf
# trip cost )
#
# Traveler $2387.05 $573.48 $570.68 $8.19 Warsaw Uprising
# Museum tour
#
# Private transportation
# $8.26 Museum of
# Accompanying NA N/A N/A Qexeupation and Freedom
#
# Jordan Dickinson's trip cost:
#  )
#
# Traveler $2387.05 $573.48 $570.68 $8.19 Warsaw Uprising
# Museum tour
#
# Private transportation
# $8.26 Museum of
# Accompanying NA N/A N/A Qexeupation and Freedom
#
#
# now downloading information on James Dolbow's trip to Lithuania' on Aug. 27, 2023 - Sept. 2, 2023
# ReadingDownloads/69LithuaniaAug. 27, 2023 - Sept. 2, 2023.pdf
#
# now scraping Downloads/69LithuaniaAug. 27, 2023 - Sept. 2, 2023.pdf
# trip cost )
#
# Traveler $2387.05 $573.48 $570.68 $8.19 Warsaw Uprising
# Museum tour
# Private transportation
# $8.26 Museum of
# Accompanying NIA N/A Qpcupation and Freedom
#
# James Dolbow's trip cost:
#  )
#
# Traveler $2387.05 $573.48 $570.68 $8.19 Warsaw Uprising
# Museum tour
# Private transportation
# $8.26 Museum of
# Accompanying NIA N/A Qpcupation and Freedom
#
#
# now downloading information on Christopher Ringer's trip to Lithuania' on Aug. 27, 2023 - Sept. 2, 2023
# ReadingDownloads/70LithuaniaAug. 27, 2023 - Sept. 2, 2023.pdf
#
# now scraping Downloads/70LithuaniaAug. 27, 2023 - Sept. 2, 2023.pdf
# trip cost )
#
# $2387.05 $573.48 $570.68 $8.19 Warsaw Uprising
# Museum tour
# Private transportation
# $8.26 Museum of
# Accompanying Qpxupation and Freedom
#
# Christopher Ringer's trip cost:
#  )
#
# $2387.05 $573.48 $570.68 $8.19 Warsaw Uprising
# Museum tour
# Private transportation
# $8.26 Museum of
# Accompanying Qpxupation and Freedom
#
#
# now downloading information on Veronica Escobar's trip to Nepal' on Aug. 25, 2023 - Sept. 2, 2023
# ReadingDownloads/71NepalAug. 25, 2023 - Sept. 2, 2023.pdf
#
# now scraping Downloads/71NepalAug. 25, 2023 - Sept. 2, 2023.pdf
# unable to scrape costs in Downloads/71NepalAug. 25, 2023 - Sept. 2, 2023.pdf
# Veronica Escobar's trip cost:
#  Error making sandwich
#
# now downloading information on Danielle Lindholm's trip to Lithuania' on Aug. 27, 2023 - Sept. 2, 2023
# ReadingDownloads/72LithuaniaAug. 27, 2023 - Sept. 2, 2023.pdf
#
# now scraping Downloads/72LithuaniaAug. 27, 2023 - Sept. 2, 2023.pdf
# trip cost )
#
# Traveler $2387.05 $573.48 $570.68 $8.19 Warsaw Uprising
# Museum tour
#
# Private transportation
# $8.26 Museum of
# Accompanying NA N/A N/A Qexeupation and Freedom
#
# Danielle Lindholm's trip cost:
#  )
#
# Traveler $2387.05 $573.48 $570.68 $8.19 Warsaw Uprising
# Museum tour
#
# Private transportation
# $8.26 Museum of
# Accompanying NA N/A N/A Qexeupation and Freedom
#
#
# now downloading information on Leslie Shedd's trip to Lithuania' on Aug. 27, 2023 - Sept. 2, 2023
# ReadingDownloads/73LithuaniaAug. 27, 2023 - Sept. 2, 2023.pdf
#
# now scraping Downloads/73LithuaniaAug. 27, 2023 - Sept. 2, 2023.pdf
# trip cost )
#
# Traveler $2387 05 $8.26 Museum of Occupati
# : . pation
# $423 $502.31 and Freedom Fights tour
# $246 Private bus transport
#
# Accompanying |N/A N/A N/A N/A
#
# Leslie Shedd's trip cost:
#  )
#
# Traveler $2387 05 $8.26 Museum of Occupati
# : . pation
# $423 $502.31 and Freedom Fights tour
# $246 Private bus transport
#
# Accompanying |N/A N/A N/A N/A
#
#
# now downloading information on Gary J. Palmer's trip to Norway' on Aug. 26, 2023 - Sept. 2, 2023
# ReadingDownloads/74NorwayAug. 26, 2023 - Sept. 2, 2023.pdf
#
# now scraping Downloads/74NorwayAug. 26, 2023 - Sept. 2, 2023.pdf
# unable to scrape costs in Downloads/74NorwayAug. 26, 2023 - Sept. 2, 2023.pdf
# Gary J. Palmer's trip cost:
#  Error making sandwich
#
# now downloading information on Jesse Von Stein's trip to Armenia Azerbaijan' on Aug. 26, 2023 - Sept. 2, 2023
# ReadingDownloads/75Armenia AzerbaijanAug. 26, 2023 - Sept. 2, 2023.pdf
#
# now scraping Downloads/75Armenia AzerbaijanAug. 26, 2023 - Sept. 2, 2023.pdf
# unable to scrape costs in Downloads/75Armenia AzerbaijanAug. 26, 2023 - Sept. 2, 2023.pdf
# Jesse Von Stein's trip cost:
#  Error making sandwich
#
# now downloading information on John Lynch's trip to Lithuania' on Aug. 27, 2023 - Sept. 2, 2023
# ReadingDownloads/76LithuaniaAug. 27, 2023 - Sept. 2, 2023.pdf
#
# now scraping Downloads/76LithuaniaAug. 27, 2023 - Sept. 2, 2023.pdf
# trip cost )
#
# Traveler $2387.05 $573.48 $570.68 $8.19 Warsaw Uprising
# Museum tour
#
# Private transportation
# $8.26 Museum of
# Accompanying NA N/A N/A Qgeupation and Freedom
#
# John Lynch's trip cost:
#  )
#
# Traveler $2387.05 $573.48 $570.68 $8.19 Warsaw Uprising
# Museum tour
#
# Private transportation
# $8.26 Museum of
# Accompanying NA N/A N/A Qgeupation and Freedom
#
#
# now downloading information on Rolando Hernandez's trip to Lithuania' on Aug. 27, 2023 - Sept. 2, 2023
# ReadingDownloads/77LithuaniaAug. 27, 2023 - Sept. 2, 2023.pdf
#
# now scraping Downloads/77LithuaniaAug. 27, 2023 - Sept. 2, 2023.pdf
# trip cost )
#
# Traveler $2387.05 $573.48 $570.68 $8.19 Warsaw Uprising
# Museum tour
#
# Private transportation
# $8.26 Museum of
# Accompanying NA N/A N/A Qexeupation and Freedom
#
# Rolando Hernandez's trip cost:
#  )
#
# Traveler $2387.05 $573.48 $570.68 $8.19 Warsaw Uprising
# Museum tour
#
# Private transportation
# $8.26 Museum of
# Accompanying NA N/A N/A Qexeupation and Freedom
#
#
# now downloading information on Heather Campbell's trip to Azerbaijan' on Aug. 26, 2023 - Sept. 2, 2023
# ReadingDownloads/78AzerbaijanAug. 26, 2023 - Sept. 2, 2023.pdf
#
# now scraping Downloads/78AzerbaijanAug. 26, 2023 - Sept. 2, 2023.pdf
# trip cost )
# Traveler
# See attachment
# (Expenses)
# Accompanying
#
# Heather Campbell's trip cost:
#  )
# Traveler
# See attachment
# (Expenses)
# Accompanying
#
#
# now downloading information on Kelly Armstrong's trip to Norway' on Aug. 26, 2023 - Sept. 1, 2023
# ReadingDownloads/79NorwayAug. 26, 2023 - Sept. 1, 2023.pdf
#
# now scraping Downloads/79NorwayAug. 26, 2023 - Sept. 1, 2023.pdf
# trip cost )
# Traveler $10,033 $1,075 $280 $692: AV, meeting
# (See Appendix) | (See Appendix) | rooms, conference
# services
# Accompanying | ¢ 49 933 $280 | $692: AV, meeting
#
# Kelly Armstrong's trip cost:
#  )
# Traveler $10,033 $1,075 $280 $692: AV, meeting
# (See Appendix) | (See Appendix) | rooms, conference
# services
# Accompanying | ¢ 49 933 $280 | $692: AV, meeting
#
#
# now downloading information on Griffin Wong's trip to United Kingdom' on Aug. 28, 2023 - Sept. 1, 2023
# ReadingDownloads/80United KingdomAug. 28, 2023 - Sept. 1, 2023.pdf
#
# now scraping Downloads/80United KingdomAug. 28, 2023 - Sept. 1, 2023.pdf
# unable to scrape costs in Downloads/80United KingdomAug. 28, 2023 - Sept. 1, 2023.pdf
# Griffin Wong's trip cost:
#  Error making sandwich
#
# now downloading information on Marc Veasey's trip to Norway' on Aug. 26, 2023 - Sept. 1, 2023
# ReadingDownloads/81NorwayAug. 26, 2023 - Sept. 1, 2023.pdf
#
# now scraping Downloads/81NorwayAug. 26, 2023 - Sept. 1, 2023.pdf
# unable to scrape costs in Downloads/81NorwayAug. 26, 2023 - Sept. 1, 2023.pdf
# Marc Veasey's trip cost:
#  Error making sandwich
#
# now downloading information on Bradley Schneider's trip to Norway' on Aug. 22, 2023 - Sept. 1, 2023
# ReadingDownloads/82NorwayAug. 22, 2023 - Sept. 1, 2023.pdf
#
# now scraping Downloads/82NorwayAug. 22, 2023 - Sept. 1, 2023.pdf
# unable to scrape costs in Downloads/82NorwayAug. 22, 2023 - Sept. 1, 2023.pdf
# Bradley Schneider's trip cost:
#  Error making sandwich
#
# now downloading information on Julia Brownley's trip to Norway' on Aug. 26, 2023 - Sept. 1, 2023
# ReadingDownloads/83NorwayAug. 26, 2023 - Sept. 1, 2023.pdf
#
# now scraping Downloads/83NorwayAug. 26, 2023 - Sept. 1, 2023.pdf
# trip cost )
#
# $1,075 $280 $692: AV, meeting
#
# (See Appendix) | (See Appendix) | rooms, conference
# services
#
# Accompanying
#
# Julia Brownley's trip cost:
#  )
#
# $1,075 $280 $692: AV, meeting
#
# (See Appendix) | (See Appendix) | rooms, conference
# services
#
# Accompanying
#
#
# now downloading information on John Joyce's trip to Norway' on Aug. 27, 2023 - Sept. 1, 2023
# ReadingDownloads/84NorwayAug. 27, 2023 - Sept. 1, 2023.pdf
#
# now scraping Downloads/84NorwayAug. 27, 2023 - Sept. 1, 2023.pdf
# trip cost )
# Traveler $4,070 $1,075 $280 $692: AV, meeting
# (See Appendix) | (See Appendix) | rooms, conference
# services
# Accompanying | ¢4 070 $280 | $692: AV, meeting
#
# John Joyce's trip cost:
#  )
# Traveler $4,070 $1,075 $280 $692: AV, meeting
# (See Appendix) | (See Appendix) | rooms, conference
# services
# Accompanying | ¢4 070 $280 | $692: AV, meeting
#
#
# now downloading information on Kathy Castor's trip to Norway' on Aug. 26, 2023 - Sept. 1, 2023
# ReadingDownloads/85NorwayAug. 26, 2023 - Sept. 1, 2023.pdf
#
# now scraping Downloads/85NorwayAug. 26, 2023 - Sept. 1, 2023.pdf
# trip cost )
# Traveler $8,036 $1,075 $280 $692: AV, meeting
# (See Appendix) | (See Appendix) | rooms, conference
# services
# Accompanying | ¢5 673 $280 | $692: AV, meeting
#
# Kathy Castor's trip cost:
#  )
# Traveler $8,036 $1,075 $280 $692: AV, meeting
# (See Appendix) | (See Appendix) | rooms, conference
# services
# Accompanying | ¢5 673 $280 | $692: AV, meeting
#
#
# now downloading information on Rick Larsen's trip to Norway' on Aug. 23, 2023 - Sept. 1, 2023
# ReadingDownloads/86NorwayAug. 23, 2023 - Sept. 1, 2023.pdf
#
# now scraping Downloads/86NorwayAug. 23, 2023 - Sept. 1, 2023.pdf
# trip cost )
# Traveler $6,828 $1,075 $280 $692: AV, meeting
# (See Appendix) | (See Appendix) | rooms, conference
# services
# Accompanying $6,828 $280 $692: AV, meeting
#
# Rick Larsen's trip cost:
#  )
# Traveler $6,828 $1,075 $280 $692: AV, meeting
# (See Appendix) | (See Appendix) | rooms, conference
# services
# Accompanying $6,828 $280 $692: AV, meeting
#
#
# now downloading information on Scott Peters's trip to Norway' on Aug. 22, 2023 - Sept. 1, 2023
# ReadingDownloads/87NorwayAug. 22, 2023 - Sept. 1, 2023.pdf
#
# now scraping Downloads/87NorwayAug. 22, 2023 - Sept. 1, 2023.pdf
# trip cost )
# Traveler $8,883 $1,075 $280 $692: AV, meeting
# (See Appendix) | (See Appendix) | rooms, conference
# services
# Accompanying $8,883 $280 | $692: AV, meeting
#
# Scott Peters's trip cost:
#  )
# Traveler $8,883 $1,075 $280 $692: AV, meeting
# (See Appendix) | (See Appendix) | rooms, conference
# services
# Accompanying $8,883 $280 | $692: AV, meeting
#
#
# now downloading information on Sean Casten's trip to Norway' on Aug. 26, 2023 - Sept. 1, 2023
# ReadingDownloads/88NorwayAug. 26, 2023 - Sept. 1, 2023.pdf
#
# now scraping Downloads/88NorwayAug. 26, 2023 - Sept. 1, 2023.pdf
# unable to scrape costs in Downloads/88NorwayAug. 26, 2023 - Sept. 1, 2023.pdf
# Sean Casten's trip cost:
#  Error making sandwich
#
# now downloading information on Debra Lesko's trip to Norway' on Aug. 26, 2023 - Sept. 1, 2023
# ReadingDownloads/89NorwayAug. 26, 2023 - Sept. 1, 2023.pdf
#
# now scraping Downloads/89NorwayAug. 26, 2023 - Sept. 1, 2023.pdf
# unable to scrape costs in Downloads/89NorwayAug. 26, 2023 - Sept. 1, 2023.pdf
# Debra Lesko's trip cost:
#  Error making sandwich
#
# now downloading information on David Rouzer's trip to Norway' on Aug. 26, 2023 - Sept. 1, 2023
# ReadingDownloads/90NorwayAug. 26, 2023 - Sept. 1, 2023.pdf
#
# now scraping Downloads/90NorwayAug. 26, 2023 - Sept. 1, 2023.pdf
# trip cost )
# Traveler $1,075 $280 $692: AV, meeting
# $8,777 (See Appendix) | (See Appendix) | rooms, conference
# services
# Accompanying
#
# David Rouzer's trip cost:
#  )
# Traveler $1,075 $280 $692: AV, meeting
# $8,777 (See Appendix) | (See Appendix) | rooms, conference
# services
# Accompanying
# now downloading information on Kevin Diamond's trip to Lithuania' on Aug. 27, 2023 - Sept. 1, 2023
# ReadingDownloads/91LithuaniaAug. 27, 2023 - Sept. 1, 2023.pdf
#
# now scraping Downloads/91LithuaniaAug. 27, 2023 - Sept. 1, 2023.pdf
# trip cost )
# Traveler $2387.05 $423 $453.43 $8.26 Museum of
# Occupation and Freedom
# Fights tour
# $246 Private bus transport
# Accompanying |N/A N/A N/A N/A
#
# Kevin Diamond's trip cost:
#  )
# Traveler $2387.05 $423 $453.43 $8.26 Museum of
# Occupation and Freedom
# Fights tour
# $246 Private bus transport
# Accompanying |N/A N/A N/A N/A
#
#
# now downloading information on Kim Schrier's trip to Norway' on Aug. 26, 2023 - Sept. 1, 2023
# ReadingDownloads/92NorwayAug. 26, 2023 - Sept. 1, 2023.pdf
#
# now scraping Downloads/92NorwayAug. 26, 2023 - Sept. 1, 2023.pdf
# trip cost )
# Traveler $1,075 $280 $692: AV, meeting
# $6,990 (See Appendix) | (See Appendix) | rooms, conference
# services
# Accompanying
#
# Kim Schrier's trip cost:
#  )
# Traveler $1,075 $280 $692: AV, meeting
# $6,990 (See Appendix) | (See Appendix) | rooms, conference
# services
# Accompanying
#
#
# now downloading information on Michael Guest's trip to Norway' on Aug. 26, 2023 - Sept. 1, 2023
# ReadingDownloads/93NorwayAug. 26, 2023 - Sept. 1, 2023.pdf
#
# now scraping Downloads/93NorwayAug. 26, 2023 - Sept. 1, 2023.pdf
# unable to scrape costs in Downloads/93NorwayAug. 26, 2023 - Sept. 1, 2023.pdf
# Michael Guest's trip cost:
#  Error making sandwich
#
# now downloading information on James Johnson's trip to Armenia Azerbaijan' on Aug. 26, 2023 - Aug. 31, 2023
# ReadingDownloads/94Armenia AzerbaijanAug. 26, 2023 - Aug. 31, 2023.pdf
#
# now scraping Downloads/94Armenia AzerbaijanAug. 26, 2023 - Aug. 31, 2023.pdf
# trip cost )
# Traveler
# See attachment
# (Expenses)
# Accompanying
#
# James Johnson's trip cost:
#  )
# Traveler
# See attachment
# (Expenses)
# Accompanying
#
#
# now downloading information on Thomas Kean, Jr.'s trip to Norway' on Aug. 26, 2023 - Aug. 30, 2023
# ReadingDownloads/95NorwayAug. 26, 2023 - Aug. 30, 2023.pdf
#
# now scraping Downloads/95NorwayAug. 26, 2023 - Aug. 30, 2023.pdf
# trip cost )
#
# Traveler
#
# $645 (See
# Appendix)* reflects
# only Oslo lodging costs
#
# Accompanying
#
# Thomas Kean, Jr.'s trip cost:
#  )
#
# Traveler
#
# $645 (See
# Appendix)* reflects
# only Oslo lodging costs
#
# Accompanying
#
#
# now downloading information on Philip Singleton's trip to Moldova' on Aug. 19, 2023 - Aug. 27, 2023
# ReadingDownloads/96MoldovaAug. 19, 2023 - Aug. 27, 2023.pdf
#
# now scraping Downloads/96MoldovaAug. 19, 2023 - Aug. 27, 2023.pdf
# unable to scrape costs in Downloads/96MoldovaAug. 19, 2023 - Aug. 27, 2023.pdf
# Philip Singleton's trip cost:
#  Error making sandwich
#
# now downloading information on Sally Fox's trip to Moldova' on Aug. 19, 2023 - Aug. 27, 2023
# ReadingDownloads/97MoldovaAug. 19, 2023 - Aug. 27, 2023.pdf
#
# now scraping Downloads/97MoldovaAug. 19, 2023 - Aug. 27, 2023.pdf
# trip cost )
#
# $789 (security)
#
# Accompanying
#
# Sally Fox's trip cost:
#  )
#
# $789 (security)
#
# Accompanying
#
#
# now downloading information on Daniel Ramirez's trip to Moldova' on Aug. 19, 2023 - Aug. 27, 2023
# ReadingDownloads/98MoldovaAug. 19, 2023 - Aug. 27, 2023.pdf
#
# now scraping Downloads/98MoldovaAug. 19, 2023 - Aug. 27, 2023.pdf
# trip cost )
#
# Traveler
#
# $4,356 $1,316 $576 $789 (security)
#
# Accompanying
#
# Daniel Ramirez's trip cost:
#  )
#
# Traveler
#
# $4,356 $1,316 $576 $789 (security)
#
# Accompanying
#
#
# failed to read Philip Singleton on Aug. 19, 2023 - Aug. 27, 2023
# failed to read Sally Fox on Aug. 19, 2023 - Aug. 27, 2023
# now downloading information on Andrew Bower's trip to Moldova' on Aug. 19, 2023 - Aug. 27, 2023
# ReadingDownloads/101MoldovaAug. 19, 2023 - Aug. 27, 2023.pdf
#
# now scraping Downloads/101MoldovaAug. 19, 2023 - Aug. 27, 2023.pdf
# trip cost )
#
# Traveler
#
# $4,356 $1,316 $576 $789 (security)
#
# Accompanying
#
# Andrew Bower's trip cost:
#  )
#
# Traveler
#
# $4,356 $1,316 $576 $789 (security)
#
# Accompanying
#
#
# now downloading information on Angele Griffin's trip to Moldova' on Aug. 19, 2023 - Aug. 27, 2023
# ReadingDownloads/102MoldovaAug. 19, 2023 - Aug. 27, 2023.pdf
#
# now scraping Downloads/102MoldovaAug. 19, 2023 - Aug. 27, 2023.pdf
# trip cost )
#
# Traveler
#
# $4,356 $1,316 $576 $789 (security)
#
# Accompanying
#
# Angele Griffin's trip cost:
#  )
#
# Traveler
#
# $4,356 $1,316 $576 $789 (security)
#
# Accompanying
#
#
# now downloading information on Nicolas Ruiz's trip to Mozambique' on Aug. 19, 2023 - Aug. 26, 2023
# ReadingDownloads/103MozambiqueAug. 19, 2023 - Aug. 26, 2023.pdf
#
# now scraping Downloads/103MozambiqueAug. 19, 2023 - Aug. 26, 2023.pdf
# trip cost )
# 158.49 Translation - $139.71
# Visa - $10,38
#
# Airport VIP Services -
# $151.59
#
# Accompanying
#
# Nicolas Ruiz's trip cost:
#  )
# 158.49 Translation - $139.71
# Visa - $10,38
#
# Airport VIP Services -
# $151.59
#
# Accompanying
#
#
# now downloading information on Arion Laws's trip to Mozambique' on Aug. 19, 2023 - Aug. 26, 2023
# ReadingDownloads/104MozambiqueAug. 19, 2023 - Aug. 26, 2023.pdf
#
# now scraping Downloads/104MozambiqueAug. 19, 2023 - Aug. 26, 2023.pdf
# trip cost )
#
# Traveler 2588.55 723.48 158.49 Translation - $139.71
# Visa - $10.38
#
# Airport VIP Services -
# $151.59
#
# Accompanying
#
# Arion Laws's trip cost:
#  )
#
# Traveler 2588.55 723.48 158.49 Translation - $139.71
# Visa - $10.38
#
# Airport VIP Services -
# $151.59
#
# Accompanying
#
#
# now downloading information on Gabrielle Howard's trip to Mozambique' on Aug. 19, 2023 - Aug. 26, 2023
# ReadingDownloads/105MozambiqueAug. 19, 2023 - Aug. 26, 2023.pdf
#
# now scraping Downloads/105MozambiqueAug. 19, 2023 - Aug. 26, 2023.pdf
# trip cost )
#
# Traveler 2588.55 723.48 158.49 Translation - $139.71
# Visa - $10.38
#
# Airport VIP Services -
# $151.59
#
# Accompanying
#
# Gabrielle Howard's trip cost:
#  )
#
# Traveler 2588.55 723.48 158.49 Translation - $139.71
# Visa - $10.38
#
# Airport VIP Services -
# $151.59
#
# Accompanying
#
#
# now downloading information on Sheyla Marimon's trip to Moldova' on Aug. 19, 2023 - Aug. 26, 2023
# ReadingDownloads/106MoldovaAug. 19, 2023 - Aug. 26, 2023.pdf
#
# now scraping Downloads/106MoldovaAug. 19, 2023 - Aug. 26, 2023.pdf
# trip cost )
#
# $789 (security)
#
# Accompanying
#
# Sheyla Marimon's trip cost:
#  )
#
# $789 (security)
#
# Accompanying
#
#
# now downloading information on Stephanie Buesser's trip to Mozambique' on Aug. 19, 2023 - Aug. 26, 2023
# ReadingDownloads/107MozambiqueAug. 19, 2023 - Aug. 26, 2023.pdf
#
# now scraping Downloads/107MozambiqueAug. 19, 2023 - Aug. 26, 2023.pdf
# trip cost )
#
# Traveler 2588.55 723.48 158.49 Translation - $139.71
# Visa - $10.38
#
# Airport VIP Services -
# $151.59
#
# Accompanying
#
# Stephanie Buesser's trip cost:
#  )
#
# Traveler 2588.55 723.48 158.49 Translation - $139.71
# Visa - $10.38
#
# Airport VIP Services -
# $151.59
#
# Accompanying
#
#
# now downloading information on Jamari Hartley's trip to Mozambique' on Aug. 19, 2023 - Aug. 26, 2023
# ReadingDownloads/108MozambiqueAug. 19, 2023 - Aug. 26, 2023.pdf
#
# now scraping Downloads/108MozambiqueAug. 19, 2023 - Aug. 26, 2023.pdf
# trip cost )
#
# Traveler 2588.55 723.48 158.49 Translation - $139.71
# Visa - $10.38
#
# Airport VIP Services -
# $151.59
#
# Accompanying
#
# Jamari Hartley's trip cost:
#  )
#
# Traveler 2588.55 723.48 158.49 Translation - $139.71
# Visa - $10.38
#
# Airport VIP Services -
# $151.59
#
# Accompanying
#
#
# now downloading information on Tracey Mann's trip to El Salvador' on Aug. 23, 2023 - Aug. 26, 2023
# ReadingDownloads/109El SalvadorAug. 23, 2023 - Aug. 26, 2023.pdf
#
# now scraping Downloads/109El SalvadorAug. 23, 2023 - Aug. 26, 2023.pdf
# trip cost )
# $1888.75 $402.20 $450
# Traveler
# Accompanying
#
# Tracey Mann's trip cost:
#  )
# $1888.75 $402.20 $450
# Traveler
# Accompanying
#
#
# now downloading information on Alyson Dallas's trip to Mozambique' on Aug. 19, 2023 - Aug. 26, 2023
# ReadingDownloads/110MozambiqueAug. 19, 2023 - Aug. 26, 2023.pdf
#
# now scraping Downloads/110MozambiqueAug. 19, 2023 - Aug. 26, 2023.pdf
# trip cost )
#
# Traveler 2588.55 723.48 158.49 Translation - $139.71
# Visa - $10.38
#
# Airport VIP Services -
# $151.59
#
# Accompanying
#
# Alyson Dallas's trip cost:
#  )
#
# Traveler 2588.55 723.48 158.49 Translation - $139.71
# Visa - $10.38
#
# Airport VIP Services -
# $151.59
#
# Accompanying
#
#
# now downloading information on Anna May's trip to Mozambique' on Aug. 19, 2023 - Aug. 26, 2023
# ReadingDownloads/111MozambiqueAug. 19, 2023 - Aug. 26, 2023.pdf
#
# now scraping Downloads/111MozambiqueAug. 19, 2023 - Aug. 26, 2023.pdf
# trip cost
# Anna May's trip cost:
#
#
# now downloading information on J. Luis Correa's trip to El Savador' on Aug. 22, 2023 - Aug. 25, 2023
# ReadingDownloads/112El SavadorAug. 22, 2023 - Aug. 25, 2023.pdf
#
# now scraping Downloads/112El SavadorAug. 22, 2023 - Aug. 25, 2023.pdf
# trip cost )
# $1619.75 $403.00 $300
# Traveler
# Accompanying
#
# J. Luis Correa's trip cost:
#  )
# $1619.75 $403.00 $300
# Traveler
# Accompanying
#
#
# now downloading information on Greg Casar's trip to Brazil' on Aug. 13, 2023 - Aug. 24, 2023
# ReadingDownloads/113BrazilAug. 13, 2023 - Aug. 24, 2023.pdf
#
# now scraping Downloads/113BrazilAug. 13, 2023 - Aug. 24, 2023.pdf
# trip cost )
#
# Interpretation: $374
# $4,546 $1 1380 $672 Photography: $384
# Hotel Conference Rooms: $98
# M&IE: $55
#
# Traveler
#
# Accompanying
#
# Greg Casar's trip cost:
#  )
#
# Interpretation: $374
# $4,546 $1 1380 $672 Photography: $384
# Hotel Conference Rooms: $98
# M&IE: $55
#
# Traveler
#
# Accompanying
#
#
# now downloading information on Greg Casar's trip to Brazil' on Aug. 13, 2023 - Aug. 24, 2023
# ReadingDownloads/114BrazilAug. 13, 2023 - Aug. 24, 2023.pdf
#
# now scraping Downloads/114BrazilAug. 13, 2023 - Aug. 24, 2023.pdf
# trip cost )
#
# Interpretation: $301
# $4,320 $1 380 $668 Photography: $434
# Hotel Conference Rooms: $120
# M&IE: $53
#
# Traveler
#
# Accompanying
#
# Greg Casar's trip cost:
#  )
#
# Interpretation: $301
# $4,320 $1 380 $668 Photography: $434
# Hotel Conference Rooms: $120
# M&IE: $53
#
# Traveler
#
# Accompanying
#
#
# now downloading information on Susan Wild's trip to Kenya' on Aug. 12, 2023 - Aug. 23, 2023
# ReadingDownloads/115KenyaAug. 12, 2023 - Aug. 23, 2023.pdf
#
# now scraping Downloads/115KenyaAug. 12, 2023 - Aug. 23, 2023.pdf
# trip cost )
#
# $8189 $1,844: AV, mtg.
# space, visa, security,
# conference services
#
# $7689 $0 $288 $1,844: AV, mtg.
# space, visa, security,
# conference services
#
# Accompanying
#
# Susan Wild's trip cost:
#  )
#
# $8189 $1,844: AV, mtg.
# space, visa, security,
# conference services
#
# $7689 $0 $288 $1,844: AV, mtg.
# space, visa, security,
# conference services
#
# Accompanying
#
#
# now downloading information on Steve Cohen's trip to Kenya' on Aug. 12, 2023 - Aug. 22, 2023
# ReadingDownloads/116KenyaAug. 12, 2023 - Aug. 22, 2023.pdf
#
# now scraping Downloads/116KenyaAug. 12, 2023 - Aug. 22, 2023.pdf
# unable to scrape costs in Downloads/116KenyaAug. 12, 2023 - Aug. 22, 2023.pdf
# Steve Cohen's trip cost:
#  Error making sandwich
#
# now downloading information on Gerardo Bonilla's trip to Chile' on Aug. 13, 2023 - Aug. 21, 2023
# ReadingDownloads/117ChileAug. 13, 2023 - Aug. 21, 2023.pdf
#
# now scraping Downloads/117ChileAug. 13, 2023 - Aug. 21, 2023.pdf
# trip cost )
#
# Traveler
#
# Interpretation: $374
# $2,409 $1 ,210 $760 Photography: $384
# Hotel Conference Rooms: $98
# Accompanying
#
# Gerardo Bonilla's trip cost:
#  )
#
# Traveler
#
# Interpretation: $374
# $2,409 $1 ,210 $760 Photography: $384
# Hotel Conference Rooms: $98
# Accompanying
#
#
# now downloading information on Renata Beca-Barragan's trip to Brazil' on Aug. 13, 2023 - Aug. 21, 2023
# ReadingDownloads/118BrazilAug. 13, 2023 - Aug. 21, 2023.pdf
#
# now scraping Downloads/118BrazilAug. 13, 2023 - Aug. 21, 2023.pdf
# trip cost )
#
# Traveler
#
# Interpretation: $374
# $2,409 $1 ,210 $616 Photography: $384
# Hotel Conference Rooms: $98
# Accompanying
#
# Renata Beca-Barragan's trip cost:
#  )
#
# Traveler
#
# Interpretation: $374
# $2,409 $1 ,210 $616 Photography: $384
# Hotel Conference Rooms: $98
# Accompanying
#
#
# now downloading information on Maxwell Frost's trip to Brazil' on Aug. 13, 2023 - Aug. 21, 2023
# ReadingDownloads/119BrazilAug. 13, 2023 - Aug. 21, 2023.pdf
#
# now scraping Downloads/119BrazilAug. 13, 2023 - Aug. 21, 2023.pdf
# unable to scrape costs in Downloads/119BrazilAug. 13, 2023 - Aug. 21, 2023.pdf
# Maxwell Frost's trip cost:
#  Error making sandwich
#
# now downloading information on Alexandria Ocasio-Cortez's trip to Brazil' on Aug. 13, 2023 - Aug. 21, 2023
# ReadingDownloads/120BrazilAug. 13, 2023 - Aug. 21, 2023.pdf
#
# now scraping Downloads/120BrazilAug. 13, 2023 - Aug. 21, 2023.pdf
# trip cost )
#
# Traveler
#
# Interpretation: $374
# $4,955 $1 945 $813 Photography: $384
# Hotel Conference Rooms: $98
# Accompanying
#
# Alexandria Ocasio-Cortez's trip cost:
#  )
#
# Traveler
#
# Interpretation: $374
# $4,955 $1 945 $813 Photography: $384
# Hotel Conference Rooms: $98
# Accompanying
#
#
# now downloading information on Samantha Ramirez Quintero's trip to Brazil' on Aug. 13, 2023 - Aug. 21, 2023
# ReadingDownloads/121BrazilAug. 13, 2023 - Aug. 21, 2023.pdf
#
# now scraping Downloads/121BrazilAug. 13, 2023 - Aug. 21, 2023.pdf
# unable to scrape costs in Downloads/121BrazilAug. 13, 2023 - Aug. 21, 2023.pdf
# Samantha Ramirez Quintero's trip cost:
#  Error making sandwich
#
# now downloading information on Gerardo Bonilla's trip to Brazil' on Aug. 13, 2023 - Aug. 21, 2023
# ReadingDownloads/122BrazilAug. 13, 2023 - Aug. 21, 2023.pdf
#
# now scraping Downloads/122BrazilAug. 13, 2023 - Aug. 21, 2023.pdf
# trip cost )
# Traveler
#
# Int tation: $301
# $2,422 $1,210 $753 erator
#
# Hotel Conference Rooms:
# $120
#
# Accompanying
#
# Gerardo Bonilla's trip cost:
#  )
# Traveler
#
# Int tation: $301
# $2,422 $1,210 $753 erator
#
# Hotel Conference Rooms:
# $120
#
# Accompanying
#
#
# failed to read Samantha Ramirez Quintero on Aug. 13, 2023 - Aug. 21, 2023
# failed to read Stephanie Trinh on Aug. 13, 2023 - Aug. 21, 2023
# now downloading information on Joaquin Castro's trip to Chile' on Aug. 16, 2023 - Aug. 21, 2023
# ReadingDownloads/125ChileAug. 16, 2023 - Aug. 21, 2023.pdf
#
# now scraping Downloads/125ChileAug. 16, 2023 - Aug. 21, 2023.pdf
# trip cost )
#
# Traveler
#
# Interpretation: $282
# $3,552 $736 $361 Photography: $210
# Hotel Conference Rooms: $98
# Accompanying
#
# Joaquin Castro's trip cost:
#  )
#
# Traveler
#
# Interpretation: $282
# $3,552 $736 $361 Photography: $210
# Hotel Conference Rooms: $98
# Accompanying
#
#
# now downloading information on Nydia Velazquez's trip to Brazil' on Aug. 13, 2023 - Aug. 21, 2023
# ReadingDownloads/126BrazilAug. 13, 2023 - Aug. 21, 2023.pdf
#
# now scraping Downloads/126BrazilAug. 13, 2023 - Aug. 21, 2023.pdf
# trip cost )
#
# Traveler
#
# Interpretation: $374
# $3,926 $1 310 $61 1 Photography: $384
# Hotel Conference Rooms: $98
# Accompanying
#
# Nydia Velazquez's trip cost:
#  )
#
# Traveler
#
# Interpretation: $374
# $3,926 $1 310 $61 1 Photography: $384
# Hotel Conference Rooms: $98
# Accompanying
#
#
# now downloading information on Nydia Velazquez's trip to Brazil' on Aug. 13, 2023 - Aug. 21, 2023
# ReadingDownloads/127BrazilAug. 13, 2023 - Aug. 21, 2023.pdf
#
# now scraping Downloads/127BrazilAug. 13, 2023 - Aug. 21, 2023.pdf
# trip cost )
#
# Inte tation: $301
# $3,939 $1,298 $604 Photography: $434
#
# Hotel Conference Rooms:
# $120
#
# Traveler
#
# Accompanying
#
# Nydia Velazquez's trip cost:
#  )
#
# Inte tation: $301
# $3,939 $1,298 $604 Photography: $434
#
# Hotel Conference Rooms:
# $120
#
# Traveler
#
# Accompanying
#
#
# now downloading information on Stephanie Trinh's trip to Brazil' on Aug. 13, 2023 - Aug. 21, 2023
# ReadingDownloads/128BrazilAug. 13, 2023 - Aug. 21, 2023.pdf
#
# now scraping Downloads/128BrazilAug. 13, 2023 - Aug. 21, 2023.pdf
# trip cost )
#
# Traveler
#
# Interpretation: $374
# $2,409 $1 ,210 $607 Photography: $384
# Hotel Conference Rooms: $98
# Accompanying
#
# Stephanie Trinh's trip cost:
#  )
#
# Traveler
#
# Interpretation: $374
# $2,409 $1 ,210 $607 Photography: $384
# Hotel Conference Rooms: $98
# Accompanying
#
#
# now downloading information on Samantha Ramirez Quintero's trip to Brazil' on Aug. 13, 2023 - Aug. 21, 2023
# ReadingDownloads/129BrazilAug. 13, 2023 - Aug. 21, 2023.pdf
#
# now scraping Downloads/129BrazilAug. 13, 2023 - Aug. 21, 2023.pdf
# trip cost )
#
# Inte tation: $301
# $2,422 $1,210 $633 Photography: $434
#
# Hotel Conference Rooms:
# $120
#
# Traveler
#
# Accompanying
#
# Samantha Ramirez Quintero's trip cost:
#  )
#
# Inte tation: $301
# $2,422 $1,210 $633 Photography: $434
#
# Hotel Conference Rooms:
# $120
#
# Traveler
#
# Accompanying
#
#
# now downloading information on Stephanie Trinh's trip to Brazil' on Aug. 13, 2023 - Aug. 21, 2023
# ReadingDownloads/130BrazilAug. 13, 2023 - Aug. 21, 2023.pdf
#
# now scraping Downloads/130BrazilAug. 13, 2023 - Aug. 21, 2023.pdf
# trip cost )
#
# Inte tation: $301
# $2,422 $1,210 $601 Photography: $434
#
# Hotel Conference Rooms:
# $120
#
# Traveler
#
# Accompanying
#
# Stephanie Trinh's trip cost:
#  )
#
# Inte tation: $301
# $2,422 $1,210 $601 Photography: $434
#
# Hotel Conference Rooms:
# $120
#
# Traveler
#
# Accompanying
#
#
# now downloading information on Alexandria Ocasio-Cortez's trip to Brazil' on Aug. 13, 2023 - Aug. 21, 2023
# ReadingDownloads/131BrazilAug. 13, 2023 - Aug. 21, 2023.pdf
#
# now scraping Downloads/131BrazilAug. 13, 2023 - Aug. 21, 2023.pdf
# trip cost )
#
# Traveler
#
# Interpretation: $374
# $4,955 $1 945 $813 Photography: $384
# Hotel Conference Rooms: $98
# Accompanying
#
# Alexandria Ocasio-Cortez's trip cost:
#  )
#
# Traveler
#
# Interpretation: $374
# $4,955 $1 945 $813 Photography: $384
# Hotel Conference Rooms: $98
# Accompanying
#
#
# now downloading information on Ami Bera's trip to Kenya' on Aug. 12, 2023 - Aug. 21, 2023
# ReadingDownloads/132KenyaAug. 12, 2023 - Aug. 21, 2023.pdf
#
# now scraping Downloads/132KenyaAug. 12, 2023 - Aug. 21, 2023.pdf
# trip cost )
#
# $1,844: AV, mtg.
#
# $10,783 space, visa, security,
# , conference services
#
# Accompanying $0 $288 $1,844: AV, mtg.
#
# Ami Bera's trip cost:
#  )
#
# $1,844: AV, mtg.
#
# $10,783 space, visa, security,
# , conference services
#
# Accompanying $0 $288 $1,844: AV, mtg.
#
#
# now downloading information on Maxwell Frost's trip to Brazil' on Aug. 13, 2023 - Aug. 21, 2023
# ReadingDownloads/133BrazilAug. 13, 2023 - Aug. 21, 2023.pdf
#
# now scraping Downloads/133BrazilAug. 13, 2023 - Aug. 21, 2023.pdf
# unable to scrape costs in Downloads/133BrazilAug. 13, 2023 - Aug. 21, 2023.pdf
# Maxwell Frost's trip cost:
#  Error making sandwich
#
# now downloading information on Merrilee Rogers's trip to Israel' on Aug. 11, 2023 - Aug. 20, 2023
# ReadingDownloads/134IsraelAug. 11, 2023 - Aug. 20, 2023.pdf
#
# now scraping Downloads/134IsraelAug. 11, 2023 - Aug. 20, 2023.pdf
# unable to scrape costs in Downloads/134IsraelAug. 11, 2023 - Aug. 20, 2023.pdf
# Merrilee Rogers's trip cost:
#  Error making sandwich
#
# now downloading information on Luis Reyes's trip to Israel' on Aug. 11, 2023 - Aug. 20, 2023
# ReadingDownloads/135IsraelAug. 11, 2023 - Aug. 20, 2023.pdf
#
# now scraping Downloads/135IsraelAug. 11, 2023 - Aug. 20, 2023.pdf
# trip cost )
#
# Traveler $2,050 ($1,500 for round $9 940 ($2,100 in |$1,238 ($900 in |$700 (guides, entry
#
# trip international flights, . . .
# $550 for bus transportation Herzliya, $840 In Herzliya, $338 fees)
#
# to and from the airport and | Jerusalem) in Jerusalem)
# between sites in Israel)
#
# Accompanying
#
# Luis Reyes's trip cost:
#  )
#
# Traveler $2,050 ($1,500 for round $9 940 ($2,100 in |$1,238 ($900 in |$700 (guides, entry
#
# trip international flights, . . .
# $550 for bus transportation Herzliya, $840 In Herzliya, $338 fees)
#
# to and from the airport and | Jerusalem) in Jerusalem)
# between sites in Israel)
#
# Accompanying
#
#
# now downloading information on Amelia Litynski's trip to Israel' on Aug. 11, 2023 - Aug. 20, 2023
# ReadingDownloads/136IsraelAug. 11, 2023 - Aug. 20, 2023.pdf
#
# now scraping Downloads/136IsraelAug. 11, 2023 - Aug. 20, 2023.pdf
# trip cost )
#
# Traveler $2,050 ($1,500 for round $9 940 ($2,100 in |$1,238 ($900 in |$700 (guides, entry
#
# trip international flights, . . .
# $550 for bus transportation Herzliya, $840 In Herzliya, $338 fees)
#
# to and from the airport and | Jerusalem) in Jerusalem)
# between sites in Israel)
#
# Accompanying
#
# Amelia Litynski's trip cost:
#  )
#
# Traveler $2,050 ($1,500 for round $9 940 ($2,100 in |$1,238 ($900 in |$700 (guides, entry
#
# trip international flights, . . .
# $550 for bus transportation Herzliya, $840 In Herzliya, $338 fees)
#
# to and from the airport and | Jerusalem) in Jerusalem)
# between sites in Israel)
#
# Accompanying
#
#
# now downloading information on John Faherty's trip to Israel' on Aug. 11, 2023 - Aug. 20, 2023
# ReadingDownloads/137IsraelAug. 11, 2023 - Aug. 20, 2023.pdf
#
# now scraping Downloads/137IsraelAug. 11, 2023 - Aug. 20, 2023.pdf
# trip cost )
#
# Traveler $2,050 ($1,500 for round $9 940 ($2,100 in |$1,238 ($900 in |$700 (guides, entry
#
# trip international flights, . . .
# $550 for bus transportation Herzliya, $840 In Herzliya, $338 fees)
#
# to and from the airport and | Jerusalem) in Jerusalem)
# between sites in Israel)
#
# Accompanying
#
# John Faherty's trip cost:
#  )
#
# Traveler $2,050 ($1,500 for round $9 940 ($2,100 in |$1,238 ($900 in |$700 (guides, entry
#
# trip international flights, . . .
# $550 for bus transportation Herzliya, $840 In Herzliya, $338 fees)
#
# to and from the airport and | Jerusalem) in Jerusalem)
# between sites in Israel)
#
# Accompanying
#
#
# now downloading information on Monika Konrad's trip to Israel' on Aug. 11, 2023 - Aug. 20, 2023
# ReadingDownloads/138IsraelAug. 11, 2023 - Aug. 20, 2023.pdf
#
# now scraping Downloads/138IsraelAug. 11, 2023 - Aug. 20, 2023.pdf
# trip cost )
#
# Traveler $2,050 ($1,500 for round $9 940 ($2,100 in |$1,238 ($900 in |$700 (guides, entry
#
# trip international flights, . . .
# $550 for bus transportation Herzliya, $840 In Herzliya, $338 fees)
#
# to and from the airport and | Jerusalem) in Jerusalem)
# between sites in Israel)
#
# Accompanying
#
# Monika Konrad's trip cost:
#  )
#
# Traveler $2,050 ($1,500 for round $9 940 ($2,100 in |$1,238 ($900 in |$700 (guides, entry
#
# trip international flights, . . .
# $550 for bus transportation Herzliya, $840 In Herzliya, $338 fees)
#
# to and from the airport and | Jerusalem) in Jerusalem)
# between sites in Israel)
#
# Accompanying
#
#
# now downloading information on Donald Barber's trip to Israel' on Aug. 11, 2023 - Aug. 20, 2023
# ReadingDownloads/139IsraelAug. 11, 2023 - Aug. 20, 2023.pdf
#
# now scraping Downloads/139IsraelAug. 11, 2023 - Aug. 20, 2023.pdf
# trip cost )
#
# Traveler $2,050 ($1,500 for round $9 940 ($2,100 in |$1,238 ($900 in |$700 (guides, entry
#
# trip international flights, . . .
# $550 for bus transportation Herzliya, $840 In Herzliya, $338 fees)
#
# to and from the airport and | Jerusalem) in Jerusalem)
# between sites in Israel)
#
# Accompanying
#
# Donald Barber's trip cost:
#  )
#
# Traveler $2,050 ($1,500 for round $9 940 ($2,100 in |$1,238 ($900 in |$700 (guides, entry
#
# trip international flights, . . .
# $550 for bus transportation Herzliya, $840 In Herzliya, $338 fees)
#
# to and from the airport and | Jerusalem) in Jerusalem)
# between sites in Israel)
#
# Accompanying
#
#
# now downloading information on John Faherty's trip to Israel' on Aug. 11, 2023 - Aug. 20, 2023
# ReadingDownloads/140IsraelAug. 11, 2023 - Aug. 20, 2023.pdf
#
# now scraping Downloads/140IsraelAug. 11, 2023 - Aug. 20, 2023.pdf
# trip cost )
#
# Traveler $2,050 ($1,500 for round $9 940 ($2,100 in |$1,238 ($900 in |$700 (guides, entry
#
# trip international flights, . . .
# $550 for bus transportation Herzliya, $840 In Herzliya, $338 fees)
#
# to and from the airport and | Jerusalem) in Jerusalem)
# between sites in Israel)
#
# Accompanying
#
# John Faherty's trip cost:
#  )
#
# Traveler $2,050 ($1,500 for round $9 940 ($2,100 in |$1,238 ($900 in |$700 (guides, entry
#
# trip international flights, . . .
# $550 for bus transportation Herzliya, $840 In Herzliya, $338 fees)
#
# to and from the airport and | Jerusalem) in Jerusalem)
# between sites in Israel)
#
# Accompanying
#
#
# now downloading information on James Dolbow's trip to Israel' on Aug. 11, 2023 - Aug. 20, 2023
# ReadingDownloads/141IsraelAug. 11, 2023 - Aug. 20, 2023.pdf
#
# now scraping Downloads/141IsraelAug. 11, 2023 - Aug. 20, 2023.pdf
# trip cost )
#
# $2,050 ($1,500 for round 1 $2,940 ($2,100 in |$1,238 ($900 in |$700 (guides, entry
#
# trip international flights, . . A
# $550 for bus transportation | Herzliya, $840 in Herzliya, $338
#
# to and from the airport and .
# between sites in Israel) Jerusalem) in Jerusalem)
#
# Accompanying
#
# James Dolbow's trip cost:
#  )
#
# $2,050 ($1,500 for round 1 $2,940 ($2,100 in |$1,238 ($900 in |$700 (guides, entry
#
# trip international flights, . . A
# $550 for bus transportation | Herzliya, $840 in Herzliya, $338
#
# to and from the airport and .
# between sites in Israel) Jerusalem) in Jerusalem)
#
# Accompanying
#
#
# now downloading information on John Castillo's trip to Israel' on Aug. 11, 2023 - Aug. 20, 2023
# ReadingDownloads/142IsraelAug. 11, 2023 - Aug. 20, 2023.pdf
#
# now scraping Downloads/142IsraelAug. 11, 2023 - Aug. 20, 2023.pdf
# trip cost )
#
# Traveler $2,050 ($1,500 for round $9 940 ($2,100 in |$1,238 ($900 in |$700 (guides, entry
#
# trip international flights, . . .
# $550 for bus transportation Herzliya, $840 In Herzliya, $338 fees)
#
# to and from the airport and | Jerusalem) in Jerusalem)
# between sites in Israel)
#
# Accompanying
#
# John Castillo's trip cost:
#  )
#
# Traveler $2,050 ($1,500 for round $9 940 ($2,100 in |$1,238 ($900 in |$700 (guides, entry
#
# trip international flights, . . .
# $550 for bus transportation Herzliya, $840 In Herzliya, $338 fees)
#
# to and from the airport and | Jerusalem) in Jerusalem)
# between sites in Israel)
#
# Accompanying
#
#
# now downloading information on Luis Reyes's trip to Israel' on Aug. 11, 2023 - Aug. 20, 2023
# ReadingDownloads/143IsraelAug. 11, 2023 - Aug. 20, 2023.pdf
#
# now scraping Downloads/143IsraelAug. 11, 2023 - Aug. 20, 2023.pdf
# trip cost )
#
# Traveler $2,050 ($1,500 for round $9 940 ($2,100 in |$1,238 ($900 in |$700 (guides, entry
#
# trip international flights, . . .
# $550 for bus transportation Herzliya, $840 In Herzliya, $338 fees)
#
# to and from the airport and | Jerusalem) in Jerusalem)
# between sites in Israel)
#
# Accompanying
#
# Luis Reyes's trip cost:
#  )
#
# Traveler $2,050 ($1,500 for round $9 940 ($2,100 in |$1,238 ($900 in |$700 (guides, entry
#
# trip international flights, . . .
# $550 for bus transportation Herzliya, $840 In Herzliya, $338 fees)
#
# to and from the airport and | Jerusalem) in Jerusalem)
# between sites in Israel)
#
# Accompanying
#
#
# now downloading information on Pete Sessions's trip to Kenya' on Aug. 12, 2023 - Aug. 19, 2023
# ReadingDownloads/144KenyaAug. 12, 2023 - Aug. 19, 2023.pdf
#
# now scraping Downloads/144KenyaAug. 12, 2023 - Aug. 19, 2023.pdf
# trip cost )
#
# $11,670 $1,844: AV, mtg.
# space, visa, security,
# conference services
#
# Accompanying
#
#
# Pete Sessions's trip cost:
#  )
#
# $11,670 $1,844: AV, mtg.
# space, visa, security,
# conference services
#
# Accompanying
#
#
#
# now downloading information on Donald Norcross's trip to Kenya' on Aug. 12, 2023 - Aug. 19, 2023
# ReadingDownloads/145KenyaAug. 12, 2023 - Aug. 19, 2023.pdf
#
# now scraping Downloads/145KenyaAug. 12, 2023 - Aug. 19, 2023.pdf
# trip cost )
#
# $12,209 ; $1,844: AV, mtg.
# space, visa, security,
# conference services
#
# Accompanying
#
#
# Donald Norcross's trip cost:
#  )
#
# $12,209 ; $1,844: AV, mtg.
# space, visa, security,
# conference services
#
# Accompanying
#
#
#
# now downloading information on Lloyd Doggett's trip to Kenya' on Aug. 7, 2023 - Aug. 19, 2023
# ReadingDownloads/146KenyaAug. 7, 2023 - Aug. 19, 2023.pdf
#
# now scraping Downloads/146KenyaAug. 7, 2023 - Aug. 19, 2023.pdf
# unable to scrape costs in Downloads/146KenyaAug. 7, 2023 - Aug. 19, 2023.pdf
# Lloyd Doggett's trip cost:
#  Error making sandwich
#
# now downloading information on John R. Curtis's trip to Kenya' on Aug. 12, 2023 - Aug. 19, 2023
# ReadingDownloads/147KenyaAug. 12, 2023 - Aug. 19, 2023.pdf
#
# now scraping Downloads/147KenyaAug. 12, 2023 - Aug. 19, 2023.pdf
# trip cost )
#
# $1,844: AV, mtg.
# space, visa, security,
#
# conference services
#
# Accompanying $1,844: AV, mtg.
#
# John R. Curtis's trip cost:
#  )
#
# $1,844: AV, mtg.
# space, visa, security,
#
# conference services
#
# Accompanying $1,844: AV, mtg.
#
#
# now downloading information on Janice Schakowsky's trip to Kenya' on Aug. 12, 2023 - Aug. 19, 2023
# ReadingDownloads/148KenyaAug. 12, 2023 - Aug. 19, 2023.pdf
#
# now scraping Downloads/148KenyaAug. 12, 2023 - Aug. 19, 2023.pdf
# trip cost )
#
# Traveler $10,000 $1,844: AV, mtg.
# space, visa, security,
# conference services
#
# Accompanying
#
# Janice Schakowsky's trip cost:
#  )
#
# Traveler $10,000 $1,844: AV, mtg.
# space, visa, security,
# conference services
#
# Accompanying
#
#
# now downloading information on Steven Horsford's trip to Kenya' on Aug. 11, 2023 - Aug. 19, 2023
# ReadingDownloads/149KenyaAug. 11, 2023 - Aug. 19, 2023.pdf
#
# now scraping Downloads/149KenyaAug. 11, 2023 - Aug. 19, 2023.pdf
# trip cost )
# Travel
# mee $10,550 $1,305 $288 $1,844: AV, mtg.
# space, visa, security,
# conference services
# Accompanying
#
# Steven Horsford's trip cost:
#  )
# Travel
# mee $10,550 $1,305 $288 $1,844: AV, mtg.
# space, visa, security,
# conference services
# Accompanying
#
#
# now downloading information on Dina Titus's trip to Kenya' on Aug. 12, 2023 - Aug. 19, 2023
# ReadingDownloads/150KenyaAug. 12, 2023 - Aug. 19, 2023.pdf
#
# now scraping Downloads/150KenyaAug. 12, 2023 - Aug. 19, 2023.pdf
# unable to scrape costs in Downloads/150KenyaAug. 12, 2023 - Aug. 19, 2023.pdf
# Dina Titus's trip cost:
#  Error making sandwich
#
# now downloading information on Zoe Lofgren's trip to Kenya' on Aug. 12, 2023 - Aug. 19, 2023
# ReadingDownloads/151KenyaAug. 12, 2023 - Aug. 19, 2023.pdf
#
# now scraping Downloads/151KenyaAug. 12, 2023 - Aug. 19, 2023.pdf
# trip cost )
#
# $12,419 $1,844: AV, mtg.
# space, visa, security,
# conference services
#
# $11,919 $0 $288 $1,844: AV, mtg.
# , space, visa, security,
# conference services
#
# Accompanying
#
# Zoe Lofgren's trip cost:
#  )
#
# $12,419 $1,844: AV, mtg.
# space, visa, security,
# conference services
#
# $11,919 $0 $288 $1,844: AV, mtg.
# , space, visa, security,
# conference services
#
# Accompanying
#
#
# now downloading information on Tracey Mann's trip to Kenya' on Aug. 12, 2023 - Aug. 19, 2023
# ReadingDownloads/152KenyaAug. 12, 2023 - Aug. 19, 2023.pdf
#
# now scraping Downloads/152KenyaAug. 12, 2023 - Aug. 19, 2023.pdf
# trip cost )
#
# $11,184 $1,844: AV, mtg.
# space, visa, security,
# conference services
#
# $10,684 $0 $288 $1,844: AV, mtg.
# , space, visa, security,
# conference services
#
# Accompanying
#
# Tracey Mann's trip cost:
#  )
#
# $11,184 $1,844: AV, mtg.
# space, visa, security,
# conference services
#
# $10,684 $0 $288 $1,844: AV, mtg.
# , space, visa, security,
# conference services
#
# Accompanying
#
#
# now downloading information on Zoe Lofgren's trip to Kenya' on Aug. 12, 2023 - Aug. 19, 2023
# ReadingDownloads/153KenyaAug. 12, 2023 - Aug. 19, 2023.pdf
#
# now scraping Downloads/153KenyaAug. 12, 2023 - Aug. 19, 2023.pdf
# No disclosure found in row 153
# now downloading information on James Baird's trip to Kenya' on Aug. 12, 2023 - Aug. 19, 2023
# ReadingDownloads/154KenyaAug. 12, 2023 - Aug. 19, 2023.pdf
#
# now scraping Downloads/154KenyaAug. 12, 2023 - Aug. 19, 2023.pdf
# trip cost )
#
# $12,147 $1,844: AV, mtg.
# space, visa, security,
# conference services
#
# Accompanying
#
#
# James Baird's trip cost:
#  )
#
# $12,147 $1,844: AV, mtg.
# space, visa, security,
# conference services
#
# Accompanying
#
#
#
# now downloading information on Beth Van Duyne's trip to Kenya' on Aug. 12, 2023 - Aug. 19, 2023
# ReadingDownloads/155KenyaAug. 12, 2023 - Aug. 19, 2023.pdf
#
# now scraping Downloads/155KenyaAug. 12, 2023 - Aug. 19, 2023.pdf
# trip cost )
#
# $10,570 $1,844: AV, mtg.
# space, visa, security,
# conference services
#
# $9,634 $0 $288 $1,844: AV, mtg.
# , space, visa, security,
# conference services
#
# Accompanying
#
# Beth Van Duyne's trip cost:
#  )
#
# $10,570 $1,844: AV, mtg.
# space, visa, security,
# conference services
#
# $9,634 $0 $288 $1,844: AV, mtg.
# , space, visa, security,
# conference services
#
# Accompanying
#
#
# now downloading information on James P. McGovern's trip to Kenya' on Aug. 12, 2023 - Aug. 19, 2023
# ReadingDownloads/156KenyaAug. 12, 2023 - Aug. 19, 2023.pdf
#
# now scraping Downloads/156KenyaAug. 12, 2023 - Aug. 19, 2023.pdf
# trip cost )
#
# $10,029 $1,844: AV, mtg.
# space, visa, security,
# conference services
#
# Accompanying
#
#
# James P. McGovern's trip cost:
#  )
#
# $10,029 $1,844: AV, mtg.
# space, visa, security,
# conference services
#
# Accompanying
#
#
#
# ...
# ReadingDownloads/1590United KingdomDec. 13, 2018 - Dec. 18, 2018.pdf
#
# now scraping Downloads/1590United KingdomDec. 13, 2018 - Dec. 18, 2018.pdf
# No disclosure found in row 1590
# now downloading information on Michael R. Turner's trip to United Kingdom' on Dec. 13, 2018 - Dec. 18, 2018
# ReadingDownloads/1591United KingdomDec. 13, 2018 - Dec. 18, 2018.pdf
#
# now scraping Downloads/1591United KingdomDec. 13, 2018 - Dec. 18, 2018.pdf
# No disclosure found in row 1591
# now downloading information on Samantha Schifrin's trip to Moldova' on Dec. 10, 2018 - Dec. 16, 2018
# ReadingDownloads/1592MoldovaDec. 10, 2018 - Dec. 16, 2018.pdf
#
# now scraping Downloads/1592MoldovaDec. 10, 2018 - Dec. 16, 2018.pdf
# unable to scrape costs in Downloads/1592MoldovaDec. 10, 2018 - Dec. 16, 2018.pdf
# Samantha Schifrin's trip cost:
#  Error making sandwich
#
# now downloading information on Christopher Maneval's trip to Cuba' on Dec. 8, 2018 - Dec. 12, 2018
# ReadingDownloads/1593CubaDec. 8, 2018 - Dec. 12, 2018.pdf
#
# now scraping Downloads/1593CubaDec. 8, 2018 - Dec. 12, 2018.pdf
# unable to scrape costs in Downloads/1593CubaDec. 8, 2018 - Dec. 12, 2018.pdf
# Christopher Maneval's trip cost:
#  Error making sandwich
#
# now downloading information on Christopher Maneval's trip to Cuba' on Dec. 9, 2018 - Dec. 12, 2018
# ReadingDownloads/1594CubaDec. 9, 2018 - Dec. 12, 2018.pdf
#
# now scraping Downloads/1594CubaDec. 9, 2018 - Dec. 12, 2018.pdf
# No disclosure found in row 1594
# now downloading information on Henry Johnson's trip to South Africa' on Nov. 30, 2018 - Dec. 4, 2018
# ReadingDownloads/1595South AfricaNov. 30, 2018 - Dec. 4, 2018.pdf
#
# now scraping Downloads/1595South AfricaNov. 30, 2018 - Dec. 4, 2018.pdf
# unable to scrape costs in Downloads/1595South AfricaNov. 30, 2018 - Dec. 4, 2018.pdf
# Henry Johnson's trip cost:
#  Error making sandwich
#
# now downloading information on Barbara Lee's trip to South Africa' on Nov. 30, 2018 - Dec. 4, 2018
# ReadingDownloads/1596South AfricaNov. 30, 2018 - Dec. 4, 2018.pdf
#
# now scraping Downloads/1596South AfricaNov. 30, 2018 - Dec. 4, 2018.pdf
# unable to scrape costs in Downloads/1596South AfricaNov. 30, 2018 - Dec. 4, 2018.pdf
# Barbara Lee's trip cost:
#  Error making sandwich
#
# now downloading information on Bobby Rush's trip to South Africa' on Nov. 30, 2018 - Dec. 4, 2018
# ReadingDownloads/1597South AfricaNov. 30, 2018 - Dec. 4, 2018.pdf
#
# now scraping Downloads/1597South AfricaNov. 30, 2018 - Dec. 4, 2018.pdf
# unable to scrape costs in Downloads/1597South AfricaNov. 30, 2018 - Dec. 4, 2018.pdf
# Bobby Rush's trip cost:
#  Error making sandwich
#
# now downloading information on Gregory Meeks's trip to South Africa' on Nov. 30, 2018 - Dec. 4, 2018
# ReadingDownloads/1598South AfricaNov. 30, 2018 - Dec. 4, 2018.pdf
#
# now scraping Downloads/1598South AfricaNov. 30, 2018 - Dec. 4, 2018.pdf
# unable to scrape costs in Downloads/1598South AfricaNov. 30, 2018 - Dec. 4, 2018.pdf
# Gregory Meeks's trip cost:
#  Error making sandwich
#
# now downloading information on Gregory Meeks's trip to South Africa' on Nov. 30, 2018 - Dec. 4, 2018
# ReadingDownloads/1599South AfricaNov. 30, 2018 - Dec. 4, 2018.pdf
#
# now scraping Downloads/1599South AfricaNov. 30, 2018 - Dec. 4, 2018.pdf
# No disclosure found in row 1599
# now downloading information on Terri Sewell's trip to South Africa' on Nov. 30, 2018 - Dec. 3, 2018
# ReadingDownloads/1600South AfricaNov. 30, 2018 - Dec. 3, 2018.pdf
#
# now scraping Downloads/1600South AfricaNov. 30, 2018 - Dec. 3, 2018.pdf
# unable to scrape costs in Downloads/1600South AfricaNov. 30, 2018 - Dec. 3, 2018.pdf
# Terri Sewell's trip cost:
#  Error making sandwich
#
# now downloading information on Sander Levin's trip to Ukraine' on Nov. 21, 2018 - Nov. 26, 2018
# ReadingDownloads/1601UkraineNov. 21, 2018 - Nov. 26, 2018.pdf
#
# now scraping Downloads/1601UkraineNov. 21, 2018 - Nov. 26, 2018.pdf
# unable to scrape costs in Downloads/1601UkraineNov. 21, 2018 - Nov. 26, 2018.pdf
# Sander Levin's trip cost:
#  Error making sandwich
#
# failed to read David Joyce on Nov. 7, 2018 - Nov. 13, 2018
# now downloading information on Fred Upton's trip to France' on Nov. 7, 2018 - Nov. 13, 2018
# ReadingDownloads/1603FranceNov. 7, 2018 - Nov. 13, 2018.pdf
#
# now scraping Downloads/1603FranceNov. 7, 2018 - Nov. 13, 2018.pdf
# unable to scrape costs in Downloads/1603FranceNov. 7, 2018 - Nov. 13, 2018.pdf
# Fred Upton's trip cost:
#  Error making sandwich
#
# now downloading information on Larry Bucshon's trip to France' on Nov. 8, 2018 - Nov. 13, 2018
# ReadingDownloads/1604FranceNov. 8, 2018 - Nov. 13, 2018.pdf
#
# now scraping Downloads/1604FranceNov. 8, 2018 - Nov. 13, 2018.pdf
# No disclosure found in row 1604
# now downloading information on Stephanie Murphy's trip to France' on Nov. 8, 2018 - Nov. 13, 2018
# ReadingDownloads/1605FranceNov. 8, 2018 - Nov. 13, 2018.pdf
#
# now scraping Downloads/1605FranceNov. 8, 2018 - Nov. 13, 2018.pdf
# unable to scrape costs in Downloads/1605FranceNov. 8, 2018 - Nov. 13, 2018.pdf
# Stephanie Murphy's trip cost:
#  Error making sandwich
#
# now downloading information on Sean Duffy's trip to France' on Nov. 8, 2018 - Nov. 13, 2018
# ReadingDownloads/1606FranceNov. 8, 2018 - Nov. 13, 2018.pdf
#
# now scraping Downloads/1606FranceNov. 8, 2018 - Nov. 13, 2018.pdf
# unable to scrape costs in Downloads/1606FranceNov. 8, 2018 - Nov. 13, 2018.pdf
# Sean Duffy's trip cost:
#  Error making sandwich
#
# now downloading information on Billy Long's trip to France' on Nov. 8, 2018 - Nov. 13, 2018
# ReadingDownloads/1607FranceNov. 8, 2018 - Nov. 13, 2018.pdf
#
# now scraping Downloads/1607FranceNov. 8, 2018 - Nov. 13, 2018.pdf
# unable to scrape costs in Downloads/1607FranceNov. 8, 2018 - Nov. 13, 2018.pdf
# Billy Long's trip cost:
#  Error making sandwich
#
# now downloading information on Darin LaHood's trip to France' on Nov. 8, 2018 - Nov. 13, 2018
# ReadingDownloads/1608FranceNov. 8, 2018 - Nov. 13, 2018.pdf
#
# now scraping Downloads/1608FranceNov. 8, 2018 - Nov. 13, 2018.pdf
# unable to scrape costs in Downloads/1608FranceNov. 8, 2018 - Nov. 13, 2018.pdf
# Darin LaHood's trip cost:
#  Error making sandwich
#
# now downloading information on Dan Newhouse's trip to France' on Nov. 8, 2018 - Nov. 13, 2018
# ReadingDownloads/1609FranceNov. 8, 2018 - Nov. 13, 2018.pdf
#
# now scraping Downloads/1609FranceNov. 8, 2018 - Nov. 13, 2018.pdf
# unable to scrape costs in Downloads/1609FranceNov. 8, 2018 - Nov. 13, 2018.pdf
# Dan Newhouse's trip cost:
#  Error making sandwich
#
# now downloading information on Sean Duffy's trip to France' on Nov. 8, 2018 - Nov. 13, 2018
# ReadingDownloads/1610FranceNov. 8, 2018 - Nov. 13, 2018.pdf
#
# now scraping Downloads/1610FranceNov. 8, 2018 - Nov. 13, 2018.pdf
# unable to scrape costs in Downloads/1610FranceNov. 8, 2018 - Nov. 13, 2018.pdf
# Sean Duffy's trip cost:
#  Error making sandwich
#
# now downloading information on Mike Kelly's trip to France' on Nov. 8, 2018 - Nov. 13, 2018
# ReadingDownloads/1611FranceNov. 8, 2018 - Nov. 13, 2018.pdf
#
# now scraping Downloads/1611FranceNov. 8, 2018 - Nov. 13, 2018.pdf
# unable to scrape costs in Downloads/1611FranceNov. 8, 2018 - Nov. 13, 2018.pdf
# Mike Kelly's trip cost:
#  Error making sandwich
#
# now downloading information on Greg Walden's trip to France' on Nov. 7, 2018 - Nov. 13, 2018
# ReadingDownloads/1612FranceNov. 7, 2018 - Nov. 13, 2018.pdf
#
# now scraping Downloads/1612FranceNov. 7, 2018 - Nov. 13, 2018.pdf
# unable to scrape costs in Downloads/1612FranceNov. 7, 2018 - Nov. 13, 2018.pdf
# Greg Walden's trip cost:
#  Error making sandwich
#
# now downloading information on Tom Reed's trip to France' on Nov. 7, 2018 - Nov. 13, 2018
# ReadingDownloads/1613FranceNov. 7, 2018 - Nov. 13, 2018.pdf
#
# now scraping Downloads/1613FranceNov. 7, 2018 - Nov. 13, 2018.pdf
# unable to scrape costs in Downloads/1613FranceNov. 7, 2018 - Nov. 13, 2018.pdf
# Tom Reed's trip cost:
#  Error making sandwich
#
# now downloading information on Bill Pascrell's trip to France' on Nov. 8, 2018 - Nov. 13, 2018
# ReadingDownloads/1614FranceNov. 8, 2018 - Nov. 13, 2018.pdf
#
# now scraping Downloads/1614FranceNov. 8, 2018 - Nov. 13, 2018.pdf
# unable to scrape costs in Downloads/1614FranceNov. 8, 2018 - Nov. 13, 2018.pdf
# Bill Pascrell's trip cost:
#  Error making sandwich
#
# now downloading information on Frank Lucas's trip to France' on Nov. 8, 2018 - Nov. 13, 2018
# ReadingDownloads/1615FranceNov. 8, 2018 - Nov. 13, 2018.pdf
#
# now scraping Downloads/1615FranceNov. 8, 2018 - Nov. 13, 2018.pdf
# unable to scrape costs in Downloads/1615FranceNov. 8, 2018 - Nov. 13, 2018.pdf
# Frank Lucas's trip cost:
#  Error making sandwich
#
# now downloading information on Rodney Davis's trip to France' on Nov. 8, 2018 - Nov. 13, 2018
# ReadingDownloads/1616FranceNov. 8, 2018 - Nov. 13, 2018.pdf
#
# now scraping Downloads/1616FranceNov. 8, 2018 - Nov. 13, 2018.pdf
# unable to scrape costs in Downloads/1616FranceNov. 8, 2018 - Nov. 13, 2018.pdf
# Rodney Davis's trip cost:
#  Error making sandwich
#
# failed to read James Himes on Nov. 8, 2018 - Nov. 13, 2018
# now downloading information on Jeff Denham's trip to France' on Nov. 8, 2018 - Nov. 13, 2018
# ReadingDownloads/1618FranceNov. 8, 2018 - Nov. 13, 2018.pdf
#
# now scraping Downloads/1618FranceNov. 8, 2018 - Nov. 13, 2018.pdf
# No disclosure found in row 1618
# now downloading information on Kevin Yoder's trip to France' on Nov. 8, 2018 - Nov. 13, 2018
# ReadingDownloads/1619FranceNov. 8, 2018 - Nov. 13, 2018.pdf
#
# now scraping Downloads/1619FranceNov. 8, 2018 - Nov. 13, 2018.pdf
# No disclosure found in row 1619
# now downloading information on James Renacci's trip to France' on Nov. 7, 2018 - Nov. 13, 2018
# ReadingDownloads/1620FranceNov. 7, 2018 - Nov. 13, 2018.pdf
#
# now scraping Downloads/1620FranceNov. 7, 2018 - Nov. 13, 2018.pdf
# unable to scrape costs in Downloads/1620FranceNov. 7, 2018 - Nov. 13, 2018.pdf
# James Renacci's trip cost:
#  Error making sandwich
#
# now downloading information on Bill Shuster's trip to France' on Nov. 6, 2018 - Nov. 13, 2018
# ReadingDownloads/1621FranceNov. 6, 2018 - Nov. 13, 2018.pdf
#
# now scraping Downloads/1621FranceNov. 6, 2018 - Nov. 13, 2018.pdf
# unable to scrape costs in Downloads/1621FranceNov. 6, 2018 - Nov. 13, 2018.pdf
# Bill Shuster's trip cost:
#  Error making sandwich
#
# now downloading information on Sean Maloney's trip to France' on Nov. 8, 2018 - Nov. 13, 2018
# ReadingDownloads/1622FranceNov. 8, 2018 - Nov. 13, 2018.pdf
#
# now scraping Downloads/1622FranceNov. 8, 2018 - Nov. 13, 2018.pdf
# unable to scrape costs in Downloads/1622FranceNov. 8, 2018 - Nov. 13, 2018.pdf
# Sean Maloney's trip cost:
#  Error making sandwich
#
# now downloading information on Mac Thornberry's trip to France' on Nov. 8, 2018 - Nov. 13, 2018
# ReadingDownloads/1623FranceNov. 8, 2018 - Nov. 13, 2018.pdf
#
# now scraping Downloads/1623FranceNov. 8, 2018 - Nov. 13, 2018.pdf
# unable to scrape costs in Downloads/1623FranceNov. 8, 2018 - Nov. 13, 2018.pdf
# Mac Thornberry's trip cost:
#  Error making sandwich
#
# now downloading information on Susan Brooks's trip to France' on Nov. 8, 2018 - Nov. 13, 2018
# ReadingDownloads/1624FranceNov. 8, 2018 - Nov. 13, 2018.pdf
#
# now scraping Downloads/1624FranceNov. 8, 2018 - Nov. 13, 2018.pdf
# unable to scrape costs in Downloads/1624FranceNov. 8, 2018 - Nov. 13, 2018.pdf
# Susan Brooks's trip cost:
#  Error making sandwich
#
# now downloading information on Kathleen Rice's trip to France' on Nov. 7, 2018 - Nov. 13, 2018
# ReadingDownloads/1625FranceNov. 7, 2018 - Nov. 13, 2018.pdf
#
# now scraping Downloads/1625FranceNov. 7, 2018 - Nov. 13, 2018.pdf
# unable to scrape costs in Downloads/1625FranceNov. 7, 2018 - Nov. 13, 2018.pdf
# Kathleen Rice's trip cost:
#  Error making sandwich
#
# now downloading information on Bill Flores's trip to France' on Nov. 8, 2018 - Nov. 13, 2018
# ReadingDownloads/1626FranceNov. 8, 2018 - Nov. 13, 2018.pdf
#
# now scraping Downloads/1626FranceNov. 8, 2018 - Nov. 13, 2018.pdf
# unable to scrape costs in Downloads/1626FranceNov. 8, 2018 - Nov. 13, 2018.pdf
# Bill Flores's trip cost:
#  Error making sandwich
#
# now downloading information on David Valadao's trip to France' on Nov. 8, 2018 - Nov. 13, 2018
# ReadingDownloads/1627FranceNov. 8, 2018 - Nov. 13, 2018.pdf
#
# now scraping Downloads/1627FranceNov. 8, 2018 - Nov. 13, 2018.pdf
# unable to scrape costs in Downloads/1627FranceNov. 8, 2018 - Nov. 13, 2018.pdf
# David Valadao's trip cost:
#  Error making sandwich
#
# now downloading information on Carlos Curbelo's trip to France' on Nov. 8, 2018 - Nov. 13, 2018
# ReadingDownloads/1628FranceNov. 8, 2018 - Nov. 13, 2018.pdf
#
# now scraping Downloads/1628FranceNov. 8, 2018 - Nov. 13, 2018.pdf
# unable to scrape costs in Downloads/1628FranceNov. 8, 2018 - Nov. 13, 2018.pdf
# Carlos Curbelo's trip cost:
#  Error making sandwich
#
# now downloading information on Peter Welch's trip to France' on Nov. 8, 2018 - Nov. 13, 2018
# ReadingDownloads/1629FranceNov. 8, 2018 - Nov. 13, 2018.pdf
#
# now scraping Downloads/1629FranceNov. 8, 2018 - Nov. 13, 2018.pdf
# unable to scrape costs in Downloads/1629FranceNov. 8, 2018 - Nov. 13, 2018.pdf
# Peter Welch's trip cost:
#  Error making sandwich
#
# now downloading information on Mike Doyle's trip to France' on Nov. 7, 2018 - Nov. 12, 2018
# ReadingDownloads/1630FranceNov. 7, 2018 - Nov. 12, 2018.pdf
#
# now scraping Downloads/1630FranceNov. 7, 2018 - Nov. 12, 2018.pdf
# unable to scrape costs in Downloads/1630FranceNov. 7, 2018 - Nov. 12, 2018.pdf
# Mike Doyle's trip cost:
#  Error making sandwich
#
# now downloading information on Josh Gottheimer's trip to France' on Nov. 7, 2018 - Nov. 12, 2018
# ReadingDownloads/1631FranceNov. 7, 2018 - Nov. 12, 2018.pdf
#
# now scraping Downloads/1631FranceNov. 7, 2018 - Nov. 12, 2018.pdf
# unable to scrape costs in Downloads/1631FranceNov. 7, 2018 - Nov. 12, 2018.pdf
# Josh Gottheimer's trip cost:
#  Error making sandwich
#
# now downloading information on John Larson's trip to France' on Nov. 7, 2018 - Nov. 12, 2018
# ReadingDownloads/1632FranceNov. 7, 2018 - Nov. 12, 2018.pdf
#
# now scraping Downloads/1632FranceNov. 7, 2018 - Nov. 12, 2018.pdf
# unable to scrape costs in Downloads/1632FranceNov. 7, 2018 - Nov. 12, 2018.pdf
# John Larson's trip cost:
#  Error making sandwich
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\anaconda\Lib\site-packages\pandas\core\indexes\range.py:345, in RangeIndex.get_loc(self, key)
#     344 try:
# --> 345     return self._range.index(new_key)
#     346 except ValueError as err:
#
# ValueError: 1633 is not in range
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[9], line 5
#       3 no_forms=[]
#       4 for i in range(55, 1634):
# ----> 5     row=df.loc[i]
#       6     raw_costs=[]
#       7     fitz_costs=[]
#
# File ~\anaconda\Lib\site-packages\pandas\core\indexing.py:1103, in _LocationIndexer.__getitem__(self, key)
#    1100 axis = self.axis or 0
#    1102 maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1103 return self._getitem_axis(maybe_callable, axis=axis)
#
# File ~\anaconda\Lib\site-packages\pandas\core\indexing.py:1343, in _LocIndexer._getitem_axis(self, key, axis)
#    1341 # fall thru to straight lookup
#    1342 self._validate_key(key, axis)
# -> 1343 return self._get_label(key, axis=axis)
#
# File ~\anaconda\Lib\site-packages\pandas\core\indexing.py:1293, in _LocIndexer._get_label(self, label, axis)
#    1291 def _get_label(self, label, axis: AxisInt):
#    1292     # GH#5567 this will fail if the label is not present in the axis.
# -> 1293     return self.obj.xs(label, axis=axis)
#
# File ~\anaconda\Lib\site-packages\pandas\core\generic.py:4095, in NDFrame.xs(self, key, axis, level, drop_level)
#    4093             new_index = index[loc]
#    4094 else:
# -> 4095     loc = index.get_loc(key)
#    4097     if isinstance(loc, np.ndarray):
#    4098         if loc.dtype == np.bool_:
#
# File ~\anaconda\Lib\site-packages\pandas\core\indexes\range.py:347, in RangeIndex.get_loc(self, key)
#     345         return self._range.index(new_key)
#     346     except ValueError as err:
# --> 347         raise KeyError(key) from err
#     348 if isinstance(key, Hashable):
#     349     raise KeyError(key)
#
# KeyError: 1633

# %%
df["Raw Costs"].value_counts()
# Out:
# Raw Costs
# Error making sandwich                                                                                                                           311
#                                                                                                                                                 105
# error                                                                                                                                            69
# )\n$6,019.15 $2,322.86 $1,223.09 $3,375.78\nTraveler\nAccompanying n/a n/a n/a n/a\n                                                             10
# )\n$4,322.73 $2,160.53 $1,035.08 $3,145.01\nTraveler breakdown attached\nAccompanying n/a n/a n/a n/a\n                                           9
#                                                                                                                                                ...
# )\n$166.66 ‘ :\nTraveler $1,395.72 $660.00 $88.00 (Visa Processing)\nAccompanying |N/A N/A N/A N/A\n                                              1
# )\n$166.66 f F\nTraveler $1,395.72 $660.00 $88.00 (Visa Processing)\nAccompanying\n                                                               1
# )\nTraveler $3,935.54 $1,004.65 $525.02 nla\n|.\nAccompanying |n/a nla n/a n/a\n                                                                  1
# )\n\nTotal Transportation Total Lodging Total Meal\nExpenses Expenses Expenses\n\n$3,935.94 $1,004.65 $525.02\n\nAccompanying |n/a n/a nia\n      1
# \n\n$189.86 Abuja,\nKaduna\n\nAccompanying\n                                                                                                      1
# Name: count, Length: 966, dtype: int64

# %%
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 df
#
# NameError: name 'df' is not defined

# %%
def splitcosts(string):
    if "Accompanying" in string:
        [left, right]=string.split("Accompanying")
        return [left, right]
    else:
        return ["error","error"]

# %%
df

# %%
df.to_csv("House Travel+Raw Costs Jan 15.csv")

# %%
len(broken_links)
# Out:
# 66

# %%
len(no_forms)
# Out:
# 69

# %%
df["Raw Traveler Cost"]=df["Raw Costs"].apply(lambda x: splitcosts(x)[0])
df["Raw Accompanying Cost"]=df["Raw Costs"].apply(lambda x:splitcosts(x)[1])

# %%
def readcosts(string):
    string=string.replace(",","")
    reg=r"\$\d+"
    numbers=re.findall(reg, string)

# %%
broken=pd.DataFrame(broken_links)
broken.to_csv("Broken Links2.csv")

# %%
no_forms_df=pd.DataFrame(no_forms)
no_forms_df.to_csv("Form Not Found2.csv")

# %%
df
# Out:
#            Unnamed: 0.1  Unnamed: 0                            Dates  \
# 0                   0.0         0.0     Dec. 6, 2023 - Dec. 12, 2023
# 1                   1.0         1.0     Dec. 6, 2023 - Dec. 12, 2023
# 2                   2.0         2.0     Dec. 6, 2023 - Dec. 11, 2023
# 3                   3.0         3.0     Dec. 6, 2023 - Dec. 11, 2023
# 4                   4.0         4.0     Dec. 7, 2023 - Dec. 11, 2023
# ...                 ...         ...                              ...
# 30046           30046.0        46.0  Sept. 27, 2007 - Sept. 30, 2007
# 30047           30047.0        47.0  Sept. 27, 2007 - Sept. 30, 2007
# 30048           30048.0        48.0  Sept. 27, 2007 - Sept. 30, 2007
# 30049           30049.0        49.0  Sept. 28, 2007 - Sept. 29, 2007
# Raw Costs           NaN         NaN                              NaN
#
#                    Traveler                  Member Party State / District  \
# 0           Vivian Moeglein         Bruce Westerman     R             AR-4
# 1             Aniela Butler         Bruce Westerman     R             AR-4
# 2            Brandon Mooney  Cathy McMorris Rodgers     R             WA-5
# 3             Craig Wheeler         Robert E. Latta     R             OH-5
# 4              Julia Letlow            Julia Letlow     R             LA-5
# ...                     ...                     ...   ...              ...
# 30046      Laurent Crenshaw            Darrell Issa     R            CA-49
# 30047       Jasper Pedersen           Robert Wexler     D            FL-19
# 30048      Laurant Crenshaw            Darrell Issa     R            CA-49
# 30049           Geoff Davis             Geoff Davis     R             KY-4
# Raw Costs               NaN                     NaN   NaN              NaN
#
#                        Destination                                Sponsor  \
# 0             United Arab Emirates        Conservative Climate Foundation
# 1             United Arab Emirates        Conservative Climate Foundation
# 2             United Arab Emirates        Conservative Climate Foundation
# 3             United Arab Emirates        Conservative Climate Foundation
# 4             United Arab Emirates           Climate Solutions Foundation
# ...                            ...                                    ...
# 30046      Cape Cod, Massachusetts          BMW Foundation Herbert Quandt
# 30047                   Boston, MA          BMW Foundation herbert Quandt
# 30048                 Cape Cod, MA          BMW Foundation Herbert Quandt
# 30049              Alburgueque, NM  Home School Legal Defense Association
# Raw Costs                      NaN                                    NaN
#
#           Filing Type                                              hrefs  \
# 0            Original  https://disclosures-clerk.house.gov/gtimages/S...
# 1            Original  https://disclosures-clerk.house.gov/gtimages/S...
# 2            Original  https://disclosures-clerk.house.gov/gtimages/S...
# 3            Original  https://disclosures-clerk.house.gov/gtimages/S...
# 4            Original  https://disclosures-clerk.house.gov/gtimages/M...
# ...               ...                                                ...
# 30046       Amendment  https://disclosures-clerk.house.gov/gtimages/S...
# 30047        Original  https://disclosures-clerk.house.gov/gtimages/S...
# 30048        Original  https://disclosures-clerk.house.gov/gtimages/S...
# 30049        Original  https://disclosures-clerk.house.gov/gtimages/M...
# Raw Costs         NaN                                                NaN
#
#                         Country  \
# 0          United Arab Emirates
# 1          United Arab Emirates
# 2          United Arab Emirates
# 3          United Arab Emirates
# 4          United Arab Emirates
# ...                         ...
# 30046                       USA
# 30047                       USA
# 30048                       USA
# 30049                       USA
# Raw Costs                   NaN
#
#                                                    Raw Costs  \
# 0          )\n\n$1,738*\n\n$1,702.90 *Averaged increased\...
# 1                                      Error making sandwich
# 2                                      Error making sandwich
# 3          )\n\nTraveler $13,703.03 $2,222.00 $451.91\n$1...
# 4          )\n\nTraveler $13,703.03 $2,222.00 $451.91\n$1...
# ...                                                      ...
# 30046
# 30047
# 30048
# 30049
# Raw Costs                                                NaN
#
#                                                     Raw Cost
# 0          )\n\n$1,738*\n\n$1,702.90 *Averaged increased\...
# 1                                      Error making sandwich
# 2                                      Error making sandwich
# 3                                                        NaN
# 4          )\n\nTraveler $13,703.03 $2,222.00 $451.91\n$1...
# ...                                                      ...
# 30046                                                    NaN
# 30047                                                    NaN
# 30048                                                    NaN
# 30049                                                    NaN
# Raw Costs                                                NaN
#
# [30051 rows x 14 columns]

# %%
def readcosts(string):
    reg=r"\$\d+"
    if type(string)==str and "Accompanying" in string:
        traveler, accompanying=string.split("Accompanying")
        traveler=traveler.replace(",","")
        accompanying=accompanying.replace(",","")
        trav_string=re.findall(reg,traveler)
        acc_string=re.findall(reg, accompanying)
        tcosts=[float(x.replace("$","")) for x in trav_string]
        acc_costs=[float(x.replace("$","")) for x in acc_string]
        traveler_costs=sum(tcosts)
        accompanying_costs=sum(acc_costs)
        return [traveler_costs, accompanying_costs]
    else:
        return ["error","error"]

# %%
#Try that function out
string="apple banana $123.50 $12 $48 Accompanying $530 $650.14"
cleancosts(string)[0]
# Out:
# 183.0

# %%
df["Traveler Cost"]=np.nan
df["Accompanying Cost"]=np.nan

# %%
df["Traveler Cost"]=df["Raw Cost"].apply(lambda x: readcosts(x)[0])
df["Accompanying Cost"]=df["Raw Cost"].apply(lambda x: readcosts(x)[1])

# %%
df
# Out:
#            Unnamed: 0.1  Unnamed: 0                            Dates  \
# 0                   0.0         0.0     Dec. 6, 2023 - Dec. 12, 2023
# 1                   1.0         1.0     Dec. 6, 2023 - Dec. 12, 2023
# 2                   2.0         2.0     Dec. 6, 2023 - Dec. 11, 2023
# 3                   3.0         3.0     Dec. 6, 2023 - Dec. 11, 2023
# 4                   4.0         4.0     Dec. 7, 2023 - Dec. 11, 2023
# ...                 ...         ...                              ...
# 30046           30046.0        46.0  Sept. 27, 2007 - Sept. 30, 2007
# 30047           30047.0        47.0  Sept. 27, 2007 - Sept. 30, 2007
# 30048           30048.0        48.0  Sept. 27, 2007 - Sept. 30, 2007
# 30049           30049.0        49.0  Sept. 28, 2007 - Sept. 29, 2007
# Raw Costs           NaN         NaN                              NaN
#
#                    Traveler                  Member Party State / District  \
# 0           Vivian Moeglein         Bruce Westerman     R             AR-4
# 1             Aniela Butler         Bruce Westerman     R             AR-4
# 2            Brandon Mooney  Cathy McMorris Rodgers     R             WA-5
# 3             Craig Wheeler         Robert E. Latta     R             OH-5
# 4              Julia Letlow            Julia Letlow     R             LA-5
# ...                     ...                     ...   ...              ...
# 30046      Laurent Crenshaw            Darrell Issa     R            CA-49
# 30047       Jasper Pedersen           Robert Wexler     D            FL-19
# 30048      Laurant Crenshaw            Darrell Issa     R            CA-49
# 30049           Geoff Davis             Geoff Davis     R             KY-4
# Raw Costs               NaN                     NaN   NaN              NaN
#
#                        Destination                                Sponsor  \
# 0             United Arab Emirates        Conservative Climate Foundation
# 1             United Arab Emirates        Conservative Climate Foundation
# 2             United Arab Emirates        Conservative Climate Foundation
# 3             United Arab Emirates        Conservative Climate Foundation
# 4             United Arab Emirates           Climate Solutions Foundation
# ...                            ...                                    ...
# 30046      Cape Cod, Massachusetts          BMW Foundation Herbert Quandt
# 30047                   Boston, MA          BMW Foundation herbert Quandt
# 30048                 Cape Cod, MA          BMW Foundation Herbert Quandt
# 30049              Alburgueque, NM  Home School Legal Defense Association
# Raw Costs                      NaN                                    NaN
#
#           Filing Type                                              hrefs  \
# 0            Original  https://disclosures-clerk.house.gov/gtimages/S...
# 1            Original  https://disclosures-clerk.house.gov/gtimages/S...
# 2            Original  https://disclosures-clerk.house.gov/gtimages/S...
# 3            Original  https://disclosures-clerk.house.gov/gtimages/S...
# 4            Original  https://disclosures-clerk.house.gov/gtimages/M...
# ...               ...                                                ...
# 30046       Amendment  https://disclosures-clerk.house.gov/gtimages/S...
# 30047        Original  https://disclosures-clerk.house.gov/gtimages/S...
# 30048        Original  https://disclosures-clerk.house.gov/gtimages/S...
# 30049        Original  https://disclosures-clerk.house.gov/gtimages/M...
# Raw Costs         NaN                                                NaN
#
#                         Country  \
# 0          United Arab Emirates
# 1          United Arab Emirates
# 2          United Arab Emirates
# 3          United Arab Emirates
# 4          United Arab Emirates
# ...                         ...
# 30046                       USA
# 30047                       USA
# 30048                       USA
# 30049                       USA
# Raw Costs                   NaN
#
#                                                    Raw Costs  \
# 0          )\n\n$1,738*\n\n$1,702.90 *Averaged increased\...
# 1                                      Error making sandwich
# 2                                      Error making sandwich
# 3          )\n\nTraveler $13,703.03 $2,222.00 $451.91\n$1...
# 4          )\n\nTraveler $13,703.03 $2,222.00 $451.91\n$1...
# ...                                                      ...
# 30046
# 30047
# 30048
# 30049
# Raw Costs                                                NaN
#
#                                                     Raw Cost Traveler Cost  \
# 0          )\n\n$1,738*\n\n$1,702.90 *Averaged increased\...        3440.0
# 1                                      Error making sandwich         error
# 2                                      Error making sandwich         error
# 3                                                        NaN         error
# 4          )\n\nTraveler $13,703.03 $2,222.00 $451.91\n$1...       30078.0
# ...                                                      ...           ...
# 30046                                                    NaN         error
# 30047                                                    NaN         error
# 30048                                                    NaN         error
# 30049                                                    NaN         error
# Raw Costs                                                NaN         error
#
#           Accompanying Cost
# 0                         0
# 1                     error
# 2                     error
# 3                     error
# 4                         0
# ...                     ...
# 30046                 error
# 30047                 error
# 30048                 error
# 30049                 error
# Raw Costs             error
#
# [30051 rows x 16 columns]

# %%
df.to_csv("House Travel+Cleaned Costs.csv")

# %%
df[df["Traveler Cost"]!="error"]
# Out:
#       Unnamed: 0.1  Unnamed: 0                          Dates  \
# 0              0.0         0.0   Dec. 6, 2023 - Dec. 12, 2023
# 4              4.0         4.0   Dec. 7, 2023 - Dec. 11, 2023
# 7              7.0         7.0   Dec. 6, 2023 - Dec. 11, 2023
# 11            11.0        11.0   Dec. 7, 2023 - Dec. 11, 2023
# 13            13.0        13.0   Dec. 7, 2023 - Dec. 11, 2023
# ...            ...         ...                            ...
# 7405        7405.0         5.0  Feb. 15, 2019 - Feb. 22, 2019
# 7423        7423.0        23.0  Feb. 15, 2019 - Feb. 22, 2019
# 7424        7424.0        24.0  Feb. 15, 2019 - Feb. 22, 2019
# 7436        7436.0        36.0  Feb. 13, 2019 - Feb. 17, 2019
# 7480        7480.0        30.0    Jan. 5, 2019 - Jan. 7, 2019
#
#                  Traveler                  Member Party State / District  \
# 0         Vivian Moeglein         Bruce Westerman     R             AR-4
# 4            Julia Letlow            Julia Letlow     R             LA-5
# 7             David Burns  Cathy McMorris Rodgers     R             WA-5
# 11       Andrew Garbarino        Andrew Garbarino     R             NY-2
# 13    Lori Chavez-DeRemer     Lori Chavez-DeRemer     R             OR-5
# ...                   ...                     ...   ...              ...
# 7405             Judy Chu                Judy Chu     D            CA-27
# 7423     Michael F. Doyle              Mike Doyle     D            PA-18
# 7424     Michael F. Doyle              Mike Doyle     D            PA-18
# 7436     Meghan Gallagher          Michael McCaul     R            TX-10
# 7480      Daniel Lipinski         Daniel Lipinski     D             IL-3
#
#                Destination                                            Sponsor  \
# 0     United Arab Emirates                    Conservative Climate Foundation
# 4     United Arab Emirates                       Climate Solutions Foundation
# 7     United Arab Emirates                    Conservative Climate Foundation
# 11    United Arab Emirates                       Climate Solutions Foundation
# 13    United Arab Emirates                       Climate Solutions Foundation
# ...                    ...                                                ...
# 7405      Tel Aviv, Israel  J Street Education Fund; Leonard Hill Charitab...
# 7423     Jerusalem, Israel  J Street Education Fund; Leonard Hill Charitab...
# 7424      Tel Aviv, Israel  J Street Education Fund; Leonard Hill Charitab...
# 7436        Abuja, Nigeria  International Republican Institute; National D...
# 7480      Indianapolis, IN         Fellowship of Catholic University Students
#
#      Filing Type                                              hrefs  \
# 0       Original  https://disclosures-clerk.house.gov/gtimages/S...
# 4       Original  https://disclosures-clerk.house.gov/gtimages/M...
# 7       Original  https://disclosures-clerk.house.gov/gtimages/S...
# 11      Original  https://disclosures-clerk.house.gov/gtimages/M...
# 13      Original  https://disclosures-clerk.house.gov/gtimages/M...
# ...          ...                                                ...
# 7405    Original  https://disclosures-clerk.house.gov/gtimages/M...
# 7423    Original  https://disclosures-clerk.house.gov/gtimages/M...
# 7424    Original  https://disclosures-clerk.house.gov/gtimages/M...
# 7436    Original  https://disclosures-clerk.house.gov/gtimages/S...
# 7480    Original  https://disclosures-clerk.house.gov/gtimages/M...
#
#                    Country                                          Raw Costs  \
# 0     United Arab Emirates  )\n\n$1,738*\n\n$1,702.90 *Averaged increased\...
# 4     United Arab Emirates  )\n\nTraveler $13,703.03 $2,222.00 $451.91\n$1...
# 7     United Arab Emirates  )\nTraveler 1,948.90 $3,050 $1,738* *Averaged ...
# 11    United Arab Emirates  )\nTraveler $13,396.74 $2,222.00 $451.91\n$13,...
# 13    United Arab Emirates  )\ndrayeles $10,913.55 $2,222.00 $451.91\n10,3...
# ...                    ...                                                ...
# 7405                Israel  \n\nPl ittached\n$11,549.69 $717.06 Rlease see...
# 7423                Israel  \n\n$2,080.00 $717.06 Please see attached\n\nd...
# 7424                Israel  \n\n$2,080.00 $717.06 Please see attached\n\nd...
# 7436         Niger Nigeria       \n\n$189.86 Abuja,\nKaduna\n\nAccompanying\n
# 7480                 India                                 \n\nAccompanying\n
#
#                                                Raw Cost Traveler Cost  \
# 0     )\n\n$1,738*\n\n$1,702.90 *Averaged increased\...        3440.0
# 4     )\n\nTraveler $13,703.03 $2,222.00 $451.91\n$1...       30078.0
# 7     )\nTraveler 1,948.90 $3,050 $1,738* *Averaged ...        4788.0
# 11    )\nTraveler $13,396.74 $2,222.00 $451.91\n$13,...       29123.0
# 13    )\ndrayeles $10,913.55 $2,222.00 $451.91\n10,3...       13586.0
# ...                                                 ...           ...
# 7405  \n\nPl ittached\n$11,549.69 $717.06 Rlease see...       12266.0
# 7423  \n\n$2,080.00 $717.06 Please see attached\n\nd...        2797.0
# 7424  \n\n$2,080.00 $717.06 Please see attached\n\nd...        2797.0
# 7436       \n\n$189.86 Abuja,\nKaduna\n\nAccompanying\n         189.0
# 7480                                 \n\nAccompanying\n             0
#
#      Accompanying Cost
# 0                    0
# 4                    0
# 7                    0
# 11                   0
# 13                   0
# ...                ...
# 7405                 0
# 7423                 0
# 7424                 0
# 7436                 0
# 7480                 0
#
# [1533 rows x 16 columns]
